# %%
# 1.- Import dependencies

import pandas as pd
import numpy as np
import json 
import requests
from citipy import citipy
import timeit


from datetime import datetime
from config import weather_api_key

# %%
# 2.- Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# 3.- Unpack lat_lngs zip object into a list. Because we only need to create a set of random latitudes and longitudes one time
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# 4.- Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(48.41240405301747, 43.38429206076154), (43.702298759386736, 147.17856829508116), (3.1313377532186593, -17.496908641463335), (-54.917509662840054, -78.73139456637989), (53.082022719238154, -159.95650742729282), (-52.68473199940933, 64.98621091346618), (-22.612711926924504, 177.55279059836278), (9.002228925180958, 106.39966971560597), (-63.32824800583478, -124.051070332997), (78.79991618272717, -113.79847571352616), (-22.320074146792862, 60.01904976810539), (9.527984293196695, 178.15240147160932), (-89.46801136745783, -134.1932752241804), (-57.731341847999936, 28.87425923202352), (3.5421168650013044, 32.95025344448368), (67.63845255191566, -159.69012959468103), (-43.23601296357119, 58.80566734171913), (-72.8701688053598, 101.65016688015561), (47.43378005368834, -150.30585105649135), (-25.284979210901213, 129.7556648054794), (24.063025523015668, 45.67579458680561), (-80.77284130856161, 0.7266482942081893), (37.68538518619846, -3.7399020156321114), (9.13557255219743, -40.299700641964336), (-0.42057654817567425, 6.353541067863489), (-78.80311687126951, -38.136219135315855), (54.161807243458725, -139.07597172112162), (30.83769405195015, -10.434119925981634), (-28.636371607582255, 60.80298490039132), (-34.563407389760236, -89.53846538744699), (-66.19958586876422, -57.08244635870045), (-85.84837472772193, -108.60969553673021), (48.17124407220277, 123.78795261241817), (36.21834920659752, -15.156799227259455), (41.20449343556109, 160.75161173097632), (12.130361015802805, -50.66025015459212), (60.411076851165774, -23.579849483084416), (35.4797683589302, 66.70412309813511), (19.77790030350363, 156.33309638422168), (-41.271024054121966, 78.07258684455365), (69.22270140698092, -50.906378514256375), (-37.52152960353687, -24.99235009092618), (-65.85142124939233, 61.54861015949814), (48.319861126649954, 37.57700040277891), (-43.33530890528234, 150.57651940801088), (-54.370197097678435, -109.11534864482039), (-25.18643233200163, 6.940609517008539), (-72.64459060962737, 38.20021618963003), (-1.1787984281610875, -134.34474263635707), (11.56644883332919, 30.23698209977755), (37.63372899703798, 123.8991587617997), (-31.779937963192694, 48.78597709245548), (74.01338083100904, 148.77150612416), (-7.621567267050466, 82.98661544636622), (-14.195662070871123, -165.2367035538431), (-5.200383586290769, -31.184284261753646), (10.520180396839422, -128.99288144750813), (61.70619075153587, 74.35084642372846), (-29.870542722243528, 170.03217829103914), (6.205066370640125, 69.86493621730045), (78.09036679367557, 165.53023813947277), (-12.393846450010912, -12.050769323181356), (42.98582969181729, 8.466741675724023), (69.93309009691009, 100.95995212471263), (21.184030014190967, 25.375998460064437), (-44.659191866161585, 167.3502095186658), (80.24467055887271, 167.66568289247698), (-63.15571449824073, -133.08012483347449), (89.82687766049884, 166.07173949805014), (75.91316667829244, -178.82115983364068), (22.927448521806, 94.07297962227017), (38.12382253720651, -106.5378036790387), (25.017673354517484, 99.75071302395907), (25.59406679450767, -32.4461597033), (74.00142331356486, -62.56823708091204), (77.91094883396735, 109.33533140513924), (30.12042172117998, 17.385413350562175), (-18.925851944113802, -128.8606588875491), (-85.20625411092016, -60.07704858999112), (-17.940838848399522, -10.811600868180847), (71.8828161371876, 89.07142983516343), (-80.87171778292671, 119.94398079151074), (51.88188349024429, -106.63319524280598), (72.14641318538821, 129.37550193444588), (40.175119663586656, 24.55407406431624), (-36.70710506755235, 109.91270980507443), (56.771670167415266, -23.636409170694122), (-64.10697710676695, 19.167753662633572), (-18.60241766616508, 165.54520565234048), (22.47318332272168, 54.961918092979516), (-85.04125505692198, -118.16952196462245), (74.1550274194071, 82.47069376749596), (-34.43068603599097, 81.01158687353319), (48.65737789813471, -173.8483068117916), (-49.27658851984851, 81.62489235080295), (-6.439149773875684, -139.38856394777233), (-66.1 ...

# %%
# 5.- Get the nearest city using the citipy module and create a list for holding the cities.
cities = []

# 6.- Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# 7.- Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# 8.- Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3eb5db8564aa00e965bac3a34dfb2af2

# %%
# 9.- Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")

# 10.- Create counters.
record_count = 1
set_count = 1

# 11.- Loop through all the cities in the list.
for i, city in enumerate(cities):

    # 12.- Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # 13.- Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # 14.- Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # 15.- Add 1 to the record count.
    record_count += 1
    
    # 16.- Run an API request for each of the cities.
    try:
        # 16.1.- Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
       
        # 16.2.-Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # 16.3.- Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # 16.4.- Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# 17.- If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# 18.- Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhniy chir
# Processing Record 2 of Set 1 | yuzhno-kurilsk
# Processing Record 3 of Set 1 | bonthe
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | bac lieu
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | kitgum
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | yulara
# Processing Record 20 of Set 1 | riyadh
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | jaen
# Processing Record 23 of Set 1 | carutapera
# Processing Record 24 of Set 1 | port-gentil
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | sitka
# Processing Record 27 of Set 1 | agadir
# Processing Record 28 of Set 1 | souillac
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | gannan
# Processing Record 31 of Set 1 | camacha
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | iracoubo
# Processing Record 34 of Set 1 | grindavik
# Processing Record 35 of Set 1 | lar gerd
# City not found. Skipping...
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | shcherbynivka
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | walvis bay
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | kaduqli
# Processing Record 47 of Set 1 | yatou
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 2 | nisia floresta
# Processing Record 2 of Set 2 | constitucion
# Processing Record 3 of Set 2 | lokosovo
# Processing Record 4 of Set 2 | ahipara
# Processing Record 5 of Set 2 | ugoofaaru
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | imperia
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | marawi
# Processing Record 11 of Set 2 | te anau
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | falam
# Processing Record 14 of Set 2 | alamosa
# Processing Record 15 of Set 2 | dali
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | surt
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | talnakh
# Processing Record 22 of Set 2 | saskatoon
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | limenaria
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | pouebo
# Processing Record 28 of Set 2 | abu dhabi
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | vila franca do campo
# Processing Record 35 of Set 2 | viedma
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | awbari
# Processing Record 38 of Set 2 | launceston
# Processing Record 39 of Set 2 | vredendal
# Processing Record 40 of Set 2 | majene
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | bombay
# Processing Record 43 of Set 2 | razdolnoye
# Processing Record 44 of Set 2 | alyangula
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | igarka
# Processing Record 48 of Set 2 | saint-pierre
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | lengshuitan
# Processing Record 2 of Set 3 | tagusao
# Processing Record 3 of Set 3 | hambantota
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | yokadouma
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | nadym
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | mayya
# Processing Record 12 of Set 3 | ostrovnoy
# Processing Record 13 of Set 3 | doha
# Processing Record 14 of Set 3 | esperance
# Processing Record 15 of Set 3 | mayo
# Processing Record 16 of Set 3 | kalmunai
# Processing Record 17 of Set 3 | kahului
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | slupca
# Processing Record 20 of Set 3 | flin flon
# Processing Record 21 of Set 3 | guerrero negro
# Processing Record 22 of Set 3 | virginia beach
# Processing Record 23 of Set 3 | aklavik
# Processing Record 24 of Set 3 | alta floresta
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | brokopondo
# Processing Record 27 of Set 3 | lumberton
# Processing Record 28 of Set 3 | sint-gillis-waas
# Processing Record 29 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 3 | berlevag
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | lagoa
# Processing Record 34 of Set 3 | dekoa
# City not found. Skipping...
# Processing Record 35 of Set 3 | oxapampa
# Processing Record 36 of Set 3 | ahuimanu
# Processing Record 37 of Set 3 | kindersley
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | ambovombe
# Processing Record 43 of Set 3 | henties bay
# Processing Record 44 of Set 3 | nago
# Processing Record 45 of Set 3 | sao joao da barra
# Processing Record 46 of Set 3 | amboasary
# Processing Record 47 of Set 3 | lorengau
# Processing Record 48 of Set 3 | buchanan
# Processing Record 49 of Set 3 | vitim
# Processing Record 50 of Set 3 | caravelas
# Processing Record 1 of Set 4 | vestmannaeyjar
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | vao
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | praia
# Processing Record 6 of Set 4 | iqaluit
# Processing Record 7 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 4 | puerto ayora
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | burns lake
# Processing Record 11 of Set 4 | sur
# Processing Record 12 of Set 4 | bealanana
# Processing Record 13 of Set 4 | fare
# Processing Record 14 of Set 4 | bollnas
# Processing Record 15 of Set 4 | kyela
# Processing Record 16 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 4 | pemba
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | playas
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | broken hill
# Processing Record 24 of Set 4 | maltahohe
# Processing Record 25 of Set 4 | kristianstad
# Processing Record 26 of Set 4 | dalby
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | lavrentiya
# Processing Record 29 of Set 4 | banjar
# Processing Record 30 of Set 4 | cape town
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | gilgit
# Processing Record 33 of Set 4 | ituango
# Processing Record 34 of Set 4 | makali
# Processing Record 35 of Set 4 | lacolle
# Processing Record 36 of Set 4 | wasilla
# Processing Record 37 of Set 4 | solec kujawski
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | presidencia roque saenz pena
# Processing Record 42 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 4 | sibu
# Processing Record 44 of Set 4 | bankfoot
# Processing Record 45 of Set 4 | cabo san lucas
# Processing Record 46 of Set 4 | nantucket
# Processing Record 47 of Set 4 | miri
# Processing Record 48 of Set 4 | oistins
# Processing Record 49 of Set 4 | clyde river
# Processing Record 50 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | saint-joseph
# Processing Record 3 of Set 5 | kavaratti
# Processing Record 4 of Set 5 | tiarei
# Processing Record 5 of Set 5 | vaini
# Processing Record 6 of Set 5 | sao sebastiao do cai
# Processing Record 7 of Set 5 | mahina
# Processing Record 8 of Set 5 | yumen
# Processing Record 9 of Set 5 | novouzensk
# Processing Record 10 of Set 5 | bandarbeyla
# Processing Record 11 of Set 5 | daltenganj
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | tahe
# Processing Record 14 of Set 5 | xai-xai
# Processing Record 15 of Set 5 | ucluelet
# Processing Record 16 of Set 5 | tocopilla
# Processing Record 17 of Set 5 | mersing
# Processing Record 18 of Set 5 | paragominas
# Processing Record 19 of Set 5 | novonukutskiy
# Processing Record 20 of Set 5 | aykhal
# Processing Record 21 of Set 5 | gotsu
# Processing Record 22 of Set 5 | krasnoye
# Processing Record 23 of Set 5 | dosso
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | ofunato
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | manokwari
# Processing Record 28 of Set 5 | rawson
# Processing Record 29 of Set 5 | saint-leu
# Processing Record 30 of Set 5 | ko samui
# Processing Record 31 of Set 5 | dingle
# Processing Record 32 of Set 5 | la ronge
# Processing Record 33 of Set 5 | alice springs
# Processing Record 34 of Set 5 | ashland
# Processing Record 35 of Set 5 | banyo
# Processing Record 36 of Set 5 | changzhou
# Processing Record 37 of Set 5 | kasempa
# Processing Record 38 of Set 5 | yamada
# Processing Record 39 of Set 5 | rundu
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | swan river
# Processing Record 43 of Set 5 | kanniyakumari
# Processing Record 44 of Set 5 | avarua
# Processing Record 45 of Set 5 | zykovo
# Processing Record 46 of Set 5 | urumqi
# Processing Record 47 of Set 5 | huarmey
# Processing Record 48 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 5 | tilichiki
# Processing Record 50 of Set 5 | galich
# Processing Record 1 of Set 6 | longyearbyen
# Processing Record 2 of Set 6 | ankazoabo
# Processing Record 3 of Set 6 | quatre cocos
# Processing Record 4 of Set 6 | kalianget
# Processing Record 5 of Set 6 | san andres
# Processing Record 6 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 6 | havre-saint-pierre
# Processing Record 8 of Set 6 | kondagaon
# Processing Record 9 of Set 6 | hofn
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | bathsheba
# Processing Record 12 of Set 6 | ojuelos de jalisco
# Processing Record 13 of Set 6 | dunedin
# Processing Record 14 of Set 6 | trincomalee
# Processing Record 15 of Set 6 | tasiilaq
# Processing Record 16 of Set 6 | partyzany
# Processing Record 17 of Set 6 | odienne
# Processing Record 18 of Set 6 | saint george
# Processing Record 19 of Set 6 | khonsa
# Processing Record 20 of Set 6 | the valley
# Processing Record 21 of Set 6 | richards bay
# Processing Record 22 of Set 6 | maceio
# Processing Record 23 of Set 6 | ust-ilimsk
# Processing Record 24 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 6 | portland
# Processing Record 26 of Set 6 | slave lake
# Processing Record 27 of Set 6 | stawell
# Processing Record 28 of Set 6 | kenai
# Processing Record 29 of Set 6 | tigil
# Processing Record 30 of Set 6 | luganville
# Processing Record 31 of Set 6 | panchagarh
# Processing Record 32 of Set 6 | umm kaddadah
# Processing Record 33 of Set 6 | guozhen
# Processing Record 34 of Set 6 | ukiah
# Processing Record 35 of Set 6 | togur
# Processing Record 36 of Set 6 | chara
# Processing Record 37 of Set 6 | sept-iles
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | ubauro
# Processing Record 40 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 6 | salalah
# Processing Record 42 of Set 6 | seybaplaya
# Processing Record 43 of Set 6 | korla
# Processing Record 44 of Set 6 | kieta
# Processing Record 45 of Set 6 | fuling
# Processing Record 46 of Set 6 | mogadishu
# Processing Record 47 of Set 6 | chongwe
# Processing Record 48 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 6 | kisangani
# Processing Record 50 of Set 6 | quetame
# Processing Record 1 of Set 7 | zharkent
# Processing Record 2 of Set 7 | norman wells
# Processing Record 3 of Set 7 | wakkanai
# Processing Record 4 of Set 7 | monrovia
# Processing Record 5 of Set 7 | christchurch
# Processing Record 6 of Set 7 | marsa matruh
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | srednekolymsk
# Processing Record 9 of Set 7 | lasa
# Processing Record 10 of Set 7 | dunmore town
# Processing Record 11 of Set 7 | kruisfontein
# Processing Record 12 of Set 7 | baculin
# Processing Record 13 of Set 7 | macapa
# Processing Record 14 of Set 7 | kayerkan
# Processing Record 15 of Set 7 | spearfish
# Processing Record 16 of Set 7 | pascagoula
# Processing Record 17 of Set 7 | hermon
# Processing Record 18 of Set 7 | san quintin
# Processing Record 19 of Set 7 | tendukheda
# Processing Record 20 of Set 7 | barranca
# Processing Record 21 of Set 7 | vila velha
# Processing Record 22 of Set 7 | ust-omchug
# Processing Record 23 of Set 7 | muzhi
# Processing Record 24 of Set 7 | cochrane
# Processing Record 25 of Set 7 | boali
# Processing Record 26 of Set 7 | anori
# Processing Record 27 of Set 7 | sidi ali
# Processing Record 28 of Set 7 | perene
# Processing Record 29 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 7 | grand gaube
# Processing Record 31 of Set 7 | praya
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | bolnisi
# Processing Record 34 of Set 7 | acapulco
# Processing Record 35 of Set 7 | portales
# Processing Record 36 of Set 7 | palaiokhora
# City not found. Skipping...
# Processing Record 37 of Set 7 | puerto quijarro
# Processing Record 38 of Set 7 | magadan
# Processing Record 39 of Set 7 | emba
# Processing Record 40 of Set 7 | neuquen
# Processing Record 41 of Set 7 | berdigestyakh
# Processing Record 42 of Set 7 | hamilton
# Processing Record 43 of Set 7 | yerbogachen
# Processing Record 44 of Set 7 | jardim
# Processing Record 45 of Set 7 | clovis
# Processing Record 46 of Set 7 | steinbach
# Processing Record 47 of Set 7 | avera
# Processing Record 48 of Set 7 | samarai
# Processing Record 49 of Set 7 | ampanihy
# Processing Record 50 of Set 7 | sisophon
# Processing Record 1 of Set 8 | north bend
# Processing Record 2 of Set 8 | shakiso
# Processing Record 3 of Set 8 | banda aceh
# Processing Record 4 of Set 8 | mayang imphal
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | vardo
# Processing Record 7 of Set 8 | sokoni
# Processing Record 8 of Set 8 | chihuahua
# Processing Record 9 of Set 8 | rio gallegos
# Processing Record 10 of Set 8 | port augusta
# Processing Record 11 of Set 8 | canutama
# Processing Record 12 of Set 8 | barra do garcas
# Processing Record 13 of Set 8 | birjand
# Processing Record 14 of Set 8 | ancud
# Processing Record 15 of Set 8 | wajir
# Processing Record 16 of Set 8 | sola
# Processing Record 17 of Set 8 | rawlins
# Processing Record 18 of Set 8 | port hardy
# Processing Record 19 of Set 8 | chulman
# Processing Record 20 of Set 8 | liancheng
# Processing Record 21 of Set 8 | tongren
# Processing Record 22 of Set 8 | khandbari
# Processing Record 23 of Set 8 | abalak
# Processing Record 24 of Set 8 | westport
# Processing Record 25 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 8 | alofi
# Processing Record 27 of Set 8 | padang
# Processing Record 28 of Set 8 | leningradskiy
# Processing Record 29 of Set 8 | gobabis
# Processing Record 30 of Set 8 | honavar
# Processing Record 31 of Set 8 | atka
# City not found. Skipping...
# Processing Record 32 of Set 8 | lata
# Processing Record 33 of Set 8 | tezu
# Processing Record 34 of Set 8 | takahagi
# Processing Record 35 of Set 8 | saldanha
# Processing Record 36 of Set 8 | mount gambier
# Processing Record 37 of Set 8 | krasnyy chikoy
# Processing Record 38 of Set 8 | pionki
# Processing Record 39 of Set 8 | voh
# Processing Record 40 of Set 8 | kiama
# Processing Record 41 of Set 8 | teya
# Processing Record 42 of Set 8 | ponta delgada
# Processing Record 43 of Set 8 | drochia
# Processing Record 44 of Set 8 | eyl
# Processing Record 45 of Set 8 | cap malheureux
# Processing Record 46 of Set 8 | olafsvik
# Processing Record 47 of Set 8 | waingapu
# Processing Record 48 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 8 | sherbakul
# Processing Record 50 of Set 8 | baruun-urt
# Processing Record 1 of Set 9 | coihaique
# Processing Record 2 of Set 9 | ewa beach
# Processing Record 3 of Set 9 | daru
# Processing Record 4 of Set 9 | paracuru
# Processing Record 5 of Set 9 | laramie
# Processing Record 6 of Set 9 | phan thiet
# Processing Record 7 of Set 9 | borogontsy
# Processing Record 8 of Set 9 | beringovskiy
# Processing Record 9 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 9 | charcas
# Processing Record 13 of Set 9 | puerto madryn
# Processing Record 14 of Set 9 | orda
# Processing Record 15 of Set 9 | mango
# Processing Record 16 of Set 9 | jinchang
# Processing Record 17 of Set 9 | wad rawah
# Processing Record 18 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 9 | coahuayana
# Processing Record 20 of Set 9 | talakan
# Processing Record 21 of Set 9 | paamiut
# Processing Record 22 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 9 | mombetsu
# Processing Record 24 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 9 | tuatapere
# Processing Record 26 of Set 9 | coquimbo
# Processing Record 27 of Set 9 | yanam
# Processing Record 28 of Set 9 | pemangkat
# Processing Record 29 of Set 9 | homer
# Processing Record 30 of Set 9 | batagay-alyta
# Processing Record 31 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 9 | oruro
# Processing Record 33 of Set 9 | nishihara
# Processing Record 34 of Set 9 | lac du bonnet
# Processing Record 35 of Set 9 | half moon bay
# Processing Record 36 of Set 9 | amboise
# Processing Record 37 of Set 9 | maniitsoq
# Processing Record 38 of Set 9 | faya
# Processing Record 39 of Set 9 | belo horizonte
# Processing Record 40 of Set 9 | sorland
# Processing Record 41 of Set 9 | chitipa
# Processing Record 42 of Set 9 | sao jose da coroa grande
# Processing Record 43 of Set 9 | bayshore gardens
# Processing Record 44 of Set 9 | kyra
# Processing Record 45 of Set 9 | raiwind
# Processing Record 46 of Set 9 | torbay
# Processing Record 47 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 9 | along
# Processing Record 49 of Set 9 | panguipulli
# Processing Record 50 of Set 9 | pangnirtung
# Processing Record 1 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 2 of Set 10 | nyurba
# Processing Record 3 of Set 10 | namatanai
# Processing Record 4 of Set 10 | bulaevo
# Processing Record 5 of Set 10 | penzance
# Processing Record 6 of Set 10 | trollhattan
# Processing Record 7 of Set 10 | shorewood
# Processing Record 8 of Set 10 | rio grande
# Processing Record 9 of Set 10 | bahia blanca
# Processing Record 10 of Set 10 | egyek
# Processing Record 11 of Set 10 | quelimane
# Processing Record 12 of Set 10 | sinjar
# Processing Record 13 of Set 10 | djambala
# Processing Record 14 of Set 10 | tselinnoye
# Processing Record 15 of Set 10 | yaan
# Processing Record 16 of Set 10 | okha
# Processing Record 17 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 10 | port lincoln
# Processing Record 19 of Set 10 | ati
# Processing Record 20 of Set 10 | sovetskiy
# Processing Record 21 of Set 10 | mporokoso
# Processing Record 22 of Set 10 | atasu
# Processing Record 23 of Set 10 | chifeng
# Processing Record 24 of Set 10 | leshukonskoye
# Processing Record 25 of Set 10 | erenhot
# Processing Record 26 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 27 of Set 10 | curvelo
# Processing Record 28 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 29 of Set 10 | hami
# Processing Record 30 of Set 10 | broome
# Processing Record 31 of Set 10 | petropavlovka
# Processing Record 32 of Set 10 | meulaboh
# Processing Record 33 of Set 10 | tigao
# Processing Record 34 of Set 10 | verkhnevilyuysk
# Processing Record 35 of Set 10 | beyneu
# Processing Record 36 of Set 10 | husavik
# Processing Record 37 of Set 10 | inta
# Processing Record 38 of Set 10 | kasongo
# Processing Record 39 of Set 10 | sao felix do xingu
# Processing Record 40 of Set 10 | udachnyy
# Processing Record 41 of Set 10 | karratha
# Processing Record 42 of Set 10 | atar
# Processing Record 43 of Set 10 | krutinka
# Processing Record 44 of Set 10 | balkanabat
# Processing Record 45 of Set 10 | dongli
# Processing Record 46 of Set 10 | lawton
# Processing Record 47 of Set 10 | okhotsk
# Processing Record 48 of Set 10 | peniche
# Processing Record 49 of Set 10 | fukagawa
# Processing Record 50 of Set 10 | florida
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | mehamn
# Processing Record 3 of Set 11 | guarda
# Processing Record 4 of Set 11 | khani
# Processing Record 5 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 6 of Set 11 | kesennuma
# City not found. Skipping...
# Processing Record 7 of Set 11 | kirando
# Processing Record 8 of Set 11 | prieta
# Processing Record 9 of Set 11 | ambulu
# Processing Record 10 of Set 11 | tonj
# Processing Record 11 of Set 11 | yenagoa
# Processing Record 12 of Set 11 | naze
# Processing Record 13 of Set 11 | paita
# Processing Record 14 of Set 11 | nicoya
# Processing Record 15 of Set 11 | uyemskiy
# Processing Record 16 of Set 11 | penaflor
# Processing Record 17 of Set 11 | geraldton
# Processing Record 18 of Set 11 | corrales
# Processing Record 19 of Set 11 | el sauzal
# Processing Record 20 of Set 11 | woodward
# Processing Record 21 of Set 11 | amuntai
# Processing Record 22 of Set 11 | deputatskiy
# Processing Record 23 of Set 11 | ketchikan
# Processing Record 24 of Set 11 | bacarra
# Processing Record 25 of Set 11 | luderitz
# Processing Record 26 of Set 11 | sorong
# Processing Record 27 of Set 11 | babu
# Processing Record 28 of Set 11 | mabaruma
# Processing Record 29 of Set 11 | bubaque
# Processing Record 30 of Set 11 | luanda
# Processing Record 31 of Set 11 | vasai
# Processing Record 32 of Set 11 | castletown
# Processing Record 33 of Set 11 | juneau
# Processing Record 34 of Set 11 | karasjok
# Processing Record 35 of Set 11 | port blair
# Processing Record 36 of Set 11 | olinda
# Processing Record 37 of Set 11 | rocha
# Processing Record 38 of Set 11 | ulladulla
# Processing Record 39 of Set 11 | adrar
# Processing Record 40 of Set 11 | stege
# Processing Record 41 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 42 of Set 11 | nouakchott
# Processing Record 43 of Set 11 | yarada
# Processing Record 44 of Set 11 | reconquista
# Processing Record 45 of Set 11 | san cristobal
# Processing Record 46 of Set 11 | touros
# Processing Record 47 of Set 11 | lask
# Processing Record 48 of Set 11 | kununurra
# Processing Record 49 of Set 11 | tibati
# Processing Record 50 of Set 11 | kushiro
# Processing Record 1 of Set 12 | sayyan
# Processing Record 2 of Set 12 | kapoeta
# Processing Record 3 of Set 12 | nemuro
# Processing Record 4 of Set 12 | russell
# Processing Record 5 of Set 12 | anshun
# Processing Record 6 of Set 12 | maragheh
# Processing Record 7 of Set 12 | chicama
# Processing Record 8 of Set 12 | ljig
# Processing Record 9 of Set 12 | gulfport
# Processing Record 10 of Set 12 | poum
# Processing Record 11 of Set 12 | simav
# Processing Record 12 of Set 12 | hirado
# Processing Record 13 of Set 12 | nakuru
# Processing Record 14 of Set 12 | shiyan
# Processing Record 15 of Set 12 | manakara
# Processing Record 16 of Set 12 | aswan
# Processing Record 17 of Set 12 | mayumba
# Processing Record 18 of Set 12 | oranjemund
# Processing Record 19 of Set 12 | mitha tiwana
# Processing Record 20 of Set 12 | zuenoula
# Processing Record 21 of Set 12 | kamenskiy
# Processing Record 22 of Set 12 | makakilo city
# Processing Record 23 of Set 12 | three hills
# Processing Record 24 of Set 12 | buraydah
# Processing Record 25 of Set 12 | atakpame
# Processing Record 26 of Set 12 | novo aripuana
# Processing Record 27 of Set 12 | alpena
# Processing Record 28 of Set 12 | la orilla
# Processing Record 29 of Set 12 | hualmay
# Processing Record 30 of Set 12 | eston
# Processing Record 31 of Set 12 | chapais
# Processing Record 32 of Set 12 | marsh harbour
# Processing Record 33 of Set 12 | shelburne
# Processing Record 34 of Set 12 | barmer
# Processing Record 35 of Set 12 | arlit
# Processing Record 36 of Set 12 | saint-augustin
# Processing Record 37 of Set 12 | hasaki
# Processing Record 38 of Set 12 | laje
# Processing Record 39 of Set 12 | adwa
# Processing Record 40 of Set 12 | puerto escondido
# Processing Record 41 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 12 | rossosh
# Processing Record 43 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 12 | tres lagoas
# Processing Record 45 of Set 12 | novobirilyussy
# Processing Record 46 of Set 12 | yuncheng
# Processing Record 47 of Set 12 | douglas
# Processing Record 48 of Set 12 | saint-felicien
# Processing Record 49 of Set 12 | qiongshan
# Processing Record 50 of Set 12 | terme
# Processing Record 1 of Set 13 | lichuan
# Processing Record 2 of Set 13 | chipinge
# Processing Record 3 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 4 of Set 13 | talcahuano
# Processing Record 5 of Set 13 | namwala
# Processing Record 6 of Set 13 | merke
# Processing Record 7 of Set 13 | lagos
# Processing Record 8 of Set 13 | gusau
# Processing Record 9 of Set 13 | parambu
# Processing Record 10 of Set 13 | moose factory
# Processing Record 11 of Set 13 | namibe
# Processing Record 12 of Set 13 | povenets
# Processing Record 13 of Set 13 | opuwo
# Processing Record 14 of Set 13 | pervomayskiy
# Processing Record 15 of Set 13 | college
# Processing Record 16 of Set 13 | rockland
# Processing Record 17 of Set 13 | lykhivka
# Processing Record 18 of Set 13 | preobrazheniye
# Processing Record 19 of Set 13 | bam
# Processing Record 20 of Set 13 | agadez
# Processing Record 21 of Set 13 | kloulklubed
# Processing Record 22 of Set 13 | puerto penasco
# Processing Record 23 of Set 13 | saint anthony
# Processing Record 24 of Set 13 | annau
# Processing Record 25 of Set 13 | beaverlodge
# Processing Record 26 of Set 13 | hirara
# Processing Record 27 of Set 13 | asau
# Processing Record 28 of Set 13 | elk
# Processing Record 29 of Set 13 | abbeville
# Processing Record 30 of Set 13 | knysna
# Processing Record 31 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | sungai padi
# Processing Record 33 of Set 13 | zyryanka
# Processing Record 34 of Set 13 | port macquarie
# Processing Record 35 of Set 13 | liverpool
# Processing Record 36 of Set 13 | canico
# Processing Record 37 of Set 13 | beidao
# Processing Record 38 of Set 13 | mount isa
# Processing Record 39 of Set 13 | bilma
# Processing Record 40 of Set 13 | covasint
# Processing Record 41 of Set 13 | novoilinsk
# Processing Record 42 of Set 13 | thinadhoo
# Processing Record 43 of Set 13 | abu kamal
# Processing Record 44 of Set 13 | ajdabiya
# Processing Record 45 of Set 13 | tazovskiy
# Processing Record 46 of Set 13 | ningxiang
# Processing Record 47 of Set 13 | bako
# Processing Record 48 of Set 13 | tura
# Processing Record 49 of Set 13 | curitibanos
# Processing Record 50 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 1 of Set 14 | waipawa
# Processing Record 2 of Set 14 | heihe
# Processing Record 3 of Set 14 | sabha
# Processing Record 4 of Set 14 | haapiti
# Processing Record 5 of Set 14 | nanortalik
# Processing Record 6 of Set 14 | egvekinot
# Processing Record 7 of Set 14 | gamba
# Processing Record 8 of Set 14 | ndele
# Processing Record 9 of Set 14 | arcachon
# Processing Record 10 of Set 14 | praia da vitoria
# Processing Record 11 of Set 14 | antalaha
# Processing Record 12 of Set 14 | ventimiglia
# Processing Record 13 of Set 14 | yalvac
# Processing Record 14 of Set 14 | dubbo
# Processing Record 15 of Set 14 | pochutla
# Processing Record 16 of Set 14 | koungheul
# Processing Record 17 of Set 14 | prince george
# Processing Record 18 of Set 14 | sao geraldo do araguaia
# Processing Record 19 of Set 14 | nuuk
# Processing Record 20 of Set 14 | kushalgarh
# Processing Record 21 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 14 | nakamura
# Processing Record 23 of Set 14 | formosa
# Processing Record 24 of Set 14 | damara
# Processing Record 25 of Set 14 | dargaville
# Processing Record 26 of Set 14 | oyama
# Processing Record 27 of Set 14 | carlisle
# Processing Record 28 of Set 14 | kyabram
# Processing Record 29 of Set 14 | great yarmouth
# Processing Record 30 of Set 14 | yar-sale
# Processing Record 31 of Set 14 | chimbote
# Processing Record 32 of Set 14 | dongzhen
# Processing Record 33 of Set 14 | bol
# Processing Record 34 of Set 14 | stephenville
# Processing Record 35 of Set 14 | parsabad
# Processing Record 36 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 14 | yeppoon
# Processing Record 38 of Set 14 | do rud
# City not found. Skipping...
# Processing Record 39 of Set 14 | mitu
# Processing Record 40 of Set 14 | tsentralnyy
# City not found. Skipping...
# Processing Record 41 of Set 14 | gaziantep
# Processing Record 42 of Set 14 | skibbereen
# Processing Record 43 of Set 14 | bajil
# Processing Record 44 of Set 14 | anahuac
# Processing Record 45 of Set 14 | buribay
# Processing Record 46 of Set 14 | montelibano
# Processing Record 47 of Set 14 | borovoy
# Processing Record 48 of Set 14 | bracebridge
# Processing Record 49 of Set 14 | biak
# Processing Record 50 of Set 14 | obihiro
# Processing Record 1 of Set 15 | hun
# Processing Record 2 of Set 15 | bereda
# Processing Record 3 of Set 15 | kaseda
# Processing Record 4 of Set 15 | punta alta
# Processing Record 5 of Set 15 | aloleng
# Processing Record 6 of Set 15 | talaya
# Processing Record 7 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 8 of Set 15 | lubao
# Processing Record 9 of Set 15 | balangir
# Processing Record 10 of Set 15 | akyab
# Processing Record 11 of Set 15 | sayansk
# Processing Record 12 of Set 15 | west bay
# Processing Record 13 of Set 15 | sechura
# Processing Record 14 of Set 15 | pokhara
# Processing Record 15 of Set 15 | byron bay
# Processing Record 16 of Set 15 | tatawin
# Processing Record 17 of Set 15 | santa cruz
# Processing Record 18 of Set 15 | la palma
# Processing Record 19 of Set 15 | new port richey
# Processing Record 20 of Set 15 | necochea
# Processing Record 21 of Set 15 | svetlogorsk
# Processing Record 22 of Set 15 | garbolovo
# Processing Record 23 of Set 15 | deneysville
# Processing Record 24 of Set 15 | makinsk
# Processing Record 25 of Set 15 | marcala
# Processing Record 26 of Set 15 | komsomolskiy
# Processing Record 27 of Set 15 | goderich
# Processing Record 28 of Set 15 | manado
# Processing Record 29 of Set 15 | ixchiguan
# Processing Record 30 of Set 15 | orchard homes
# Processing Record 31 of Set 15 | smithers
# Processing Record 32 of Set 15 | houthulst
# Processing Record 33 of Set 15 | cayenne
# Processing Record 34 of Set 15 | atambua
# Processing Record 35 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 36 of Set 15 | a
# City not found. Skipping...
# Processing Record 37 of Set 15 | oum hadjer
# Processing Record 38 of Set 15 | nemsova
# Processing Record 39 of Set 15 | appleton
# Processing Record 40 of Set 15 | hue
# Processing Record 41 of Set 15 | ixtapa
# Processing Record 42 of Set 15 | yermakovskoye
# Processing Record 43 of Set 15 | plettenberg bay
# Processing Record 44 of Set 15 | pisco
# Processing Record 45 of Set 15 | akropong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 19.- Number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 690

# %%
# 20.- Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nizhniy Chir      RU  48.3597   43.0865     49.14        86         100
# 1  Yuzhno-Kurilsk      RU  44.0306  145.8556     47.32        99          76
# 2          Bonthe      SL   7.5264  -12.5050     81.09        82          22
# 3    Punta Arenas      CL -53.1500  -70.9167     46.51        76           0
# 4          Bethel      US  41.3712  -73.4140     78.35        46          40
# 5  Saint-Philippe      RE -21.3585   55.7679     76.59        82          33
# 6         Isangel      VU -19.5500  169.2667     75.51        68         100
# 7        Bac Lieu      VN   9.2850  105.7244     83.07        77         100
# 8         Rikitea      PF -23.1203 -134.9692     77.54        81           6
# 9     Yellowknife      CA  62.4560 -114.3525     37.27        72         100
#
#    Wind Speed Current Description
# 0       23.11     overcast clouds
# 1       10.51       broken clouds
# 2        5.88          few clouds
# 3        1.14           clear sky
# 4        8.05    scattered clouds
# 5        3.76    scattered clouds
# 6       20.09     overcast clouds
# 7        5.53     overcast clouds
# 8       20.42           clear sky
# 9        4.00     overcast clouds

# %%
# 20.- Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder

output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
