# %%
# 1.- Import dependencies

import pandas as pd
import numpy as np
import json 
import requests
from citipy import citipy
import timeit


from datetime import datetime
from config import weather_api_key

# %%
# 2.- Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# 3.- Unpack lat_lngs zip object into a list. Because we only need to create a set of random latitudes and longitudes one time
lat_lngs = zip(lats, lngs)
lat_lngs

# one can only unzip a zipped tuple once before it is removed from the computer's memory
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on

# %%
# 4.- Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-30.826008249786263, 65.86617077819159), (49.0392069641083, -121.00226805581113), (-76.58762588831435, -58.77655577639615), (60.06959927815009, 18.461877170088883), (-25.012960189494365, 107.43205954825743), (21.685395968620995, 30.06468676614287), (64.00270317449406, 116.83444246181642), (18.66771311028691, -19.082529931455753), (67.56593244671089, 137.34783939490308), (29.309455783917457, -69.76915296490685), (85.92842288379987, 137.19296647397897), (1.9132944206333775, 94.70422795148528), (-75.44741982234054, -135.13450372458473), (-59.62629782274746, -52.40234286965145), (55.00422132906786, -91.37043898190828), (55.69600919778233, 81.22479187366599), (-87.09159027436563, 30.243571829721986), (-88.5554286844701, -70.38746062943316), (52.35861265899484, 10.041348643772551), (-73.17834738172635, 83.43847528619904), (53.559556650340255, -61.650034017979124), (49.08541782258587, -98.43924206160173), (-41.67683849467432, -164.44119366154186), (15.868576762773102, 42.69745166816773), (-21.282726118489634, 178.29063516752979), (68.35813655068873, 47.00683837755017), (-35.67026274809503, 8.525666463034128), (38.07165450643595, -137.50948722053445), (46.44547385977265, -136.12217553688834), (77.90850192138655, 7.259848358279584), (-14.16118663149561, 140.92670566446282), (62.51287434711364, 44.559569932080194), (13.809196943388159, 79.00140064995475), (52.62501773603816, -66.82344177799807), (-64.57049915414936, -69.09715523822574), (-58.77450128001802, -112.07970897605422), (-25.961036961937765, -179.64680775906908), (34.264010405756665, 41.745754642726894), (-36.698271699464414, -49.72882270017422), (34.781227695965626, 72.95174827006517), (-26.4313570363242, 22.976117239786646), (55.09174391299308, -43.69756892290448), (24.10510121021393, -174.7287963380905), (-13.92723987341384, -99.76205620231153), (-68.76888032631506, 44.071288568325656), (-35.51215957317638, -86.53973607407612), (-78.81977522469163, 143.31697416444496), (-73.79153792659757, -174.83933565368912), (26.34712177612269, -121.19168447848051), (35.59227994065921, 138.51995368314897), (-59.346847383163535, -22.82081635300233), (48.643534558529666, -17.95003674903967), (48.954930520587425, 31.037051213865396), (77.57574407647121, -23.445510664847973), (-52.625730422525336, -27.14160880397114), (12.545572275777701, 145.41417182253923), (-41.61764935669957, -72.65088174639986), (-39.74744701399518, -73.38010688399497), (36.10356720481242, 56.53426066637746), (13.913681704455641, 19.66047461423841), (81.08424538363906, 103.36381061292087), (48.27792004800176, 19.565796075059097), (54.59068676402879, 143.39377207768877), (-59.286403892151014, 30.604654948565752), (60.58213694110157, 33.250987493259856), (-41.879676306603514, 76.98599508822372), (7.504672472408203, 139.05863928339102), (-46.71091519070363, -60.98013054317424), (-58.830365984863334, -61.6497844324237), (46.82670975177521, -121.48416471914899), (20.481610780210275, 129.88067666559868), (-45.22348942047055, 102.6508452046786), (87.9458978579552, 26.22601642022505), (43.36361425163008, -2.2128154759116967), (18.08060239795134, 47.60943729314556), (70.63671212154264, -71.66727566994604), (63.99704210663708, 92.8411319921745), (30.014086870078202, 55.39600753633556), (74.39819845081152, -78.93148545088863), (75.7064387215948, 79.25399079401592), (-31.697001728895586, -158.19155562248264), (-58.397041190722774, -90.90319130719476), (-77.57633670255282, 108.35692579209172), (-84.25682462161889, 159.17883109559568), (28.86461084783612, -143.2405191296573), (73.05044204992447, -118.47344375382781), (-77.01136840862796, -82.81573645999072), (46.76702259571593, -54.51432679451459), (-64.70048228396608, -93.80910400465238), (76.74768548614372, 121.19653896159315), (-23.180639622508778, -164.43907317496488), (-57.718401094789385, -113.47526109488179), (46.48840389961299, 82.63962277725699), (-31.848755348271638, 168.54309266487957), (-81.63023930520494, -135.91505479778516), (25.205334868915415, 97.02406927430053), (- ...

# %%
# 5.- Get the nearest city using the citipy module and create a list for holding the cities.
cities = []

# 6.- Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3eb5db8564aa00e965bac3a34dfb2af2

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | hope
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | norrtalje
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | marawi
# Processing Record 7 of Set 1 | nyurba
# Processing Record 8 of Set 1 | nouadhibou
# Processing Record 9 of Set 1 | batagay
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | meulaboh
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | sioux lookout
# Processing Record 15 of Set 1 | chulym
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | lehrte
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | saint-augustin
# Processing Record 20 of Set 1 | morden
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | bajil
# Processing Record 23 of Set 1 | isangel
# Processing Record 24 of Set 1 | leshukonskoye
# Processing Record 25 of Set 1 | saldanha
# Processing Record 26 of Set 1 | fortuna
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | alyangula
# Processing Record 30 of Set 1 | verkhnyaya toyma
# Processing Record 31 of Set 1 | rayachoti
# Processing Record 32 of Set 1 | sept-iles
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | rawah
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | baffa
# Processing Record 38 of Set 1 | tsabong
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | san quintin
# Processing Record 46 of Set 1 | ryuo
# Processing Record 47 of Set 1 | dingle
# Processing Record 48 of Set 1 | yerky
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | cidreira
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | puerto montt
# Processing Record 3 of Set 2 | valdivia
# Processing Record 4 of Set 2 | sabzevar
# Processing Record 5 of Set 2 | oum hadjer
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | lucenec
# Processing Record 8 of Set 2 | okha
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | lodeynoye pole
# Processing Record 11 of Set 2 | rawson
# Processing Record 12 of Set 2 | enumclaw
# Processing Record 13 of Set 2 | itoman
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | zarautz
# Processing Record 16 of Set 2 | najran
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | teya
# Processing Record 19 of Set 2 | shahr-e babak
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | marystown
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 2 | ahipara
# Processing Record 30 of Set 2 | myitkyina
# Processing Record 31 of Set 2 | saint-leu
# Processing Record 32 of Set 2 | yulara
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | puerto del rosario
# Processing Record 35 of Set 2 | dalvik
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | frunze
# Processing Record 39 of Set 2 | manaure
# Processing Record 40 of Set 2 | mataura
# Processing Record 41 of Set 2 | koslan
# Processing Record 42 of Set 2 | tual
# Processing Record 43 of Set 2 | tura
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | karakol
# Processing Record 46 of Set 2 | zyryanka
# Processing Record 47 of Set 2 | lasa
# Processing Record 48 of Set 2 | kapit
# Processing Record 49 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 2 | bilibino
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | ponta delgada
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | cape town
# Processing Record 6 of Set 3 | koumra
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | kahuta
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | lithakia
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 3 | yatou
# Processing Record 16 of Set 3 | qinzhou
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | nishihara
# Processing Record 20 of Set 3 | kytlym
# City not found. Skipping...
# Processing Record 21 of Set 3 | waipawa
# Processing Record 22 of Set 3 | changli
# Processing Record 23 of Set 3 | pontes e lacerda
# Processing Record 24 of Set 3 | kohlu
# Processing Record 25 of Set 3 | sorland
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 3 | bonavista
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | new norfolk
# Processing Record 31 of Set 3 | namatanai
# Processing Record 32 of Set 3 | lyuban
# Processing Record 33 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 34 of Set 3 | nantucket
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | pombas
# Processing Record 37 of Set 3 | natal
# Processing Record 38 of Set 3 | stonewall
# Processing Record 39 of Set 3 | birjand
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | limenaria
# Processing Record 42 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 3 | narsaq
# Processing Record 45 of Set 3 | padang
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | palasa
# Processing Record 50 of Set 3 | yumen
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | sonda
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | north bend
# Processing Record 6 of Set 4 | hofn
# Processing Record 7 of Set 4 | peniche
# Processing Record 8 of Set 4 | codrington
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | sao filipe
# Processing Record 13 of Set 4 | atuona
# Processing Record 14 of Set 4 | komsomolskiy
# Processing Record 15 of Set 4 | grand gaube
# Processing Record 16 of Set 4 | cayenne
# Processing Record 17 of Set 4 | vernon
# Processing Record 18 of Set 4 | havre-saint-pierre
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | jamestown
# Processing Record 21 of Set 4 | dudinka
# Processing Record 22 of Set 4 | machali
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | perth
# Processing Record 25 of Set 4 | viksoyri
# City not found. Skipping...
# Processing Record 26 of Set 4 | chokurdakh
# Processing Record 27 of Set 4 | takaka
# Processing Record 28 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 4 | mitsamiouli
# Processing Record 30 of Set 4 | douglas
# Processing Record 31 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 4 | kwinana
# Processing Record 33 of Set 4 | mahon
# Processing Record 34 of Set 4 | borama
# City not found. Skipping...
# Processing Record 35 of Set 4 | korla
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | tateyama
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | klyuchi
# Processing Record 40 of Set 4 | bairiki
# Processing Record 41 of Set 4 | yangambi
# Processing Record 42 of Set 4 | shelburne
# Processing Record 43 of Set 4 | kentau
# Processing Record 44 of Set 4 | cosala
# Processing Record 45 of Set 4 | darhan
# Processing Record 46 of Set 4 | upata
# Processing Record 47 of Set 4 | vila velha
# Processing Record 48 of Set 4 | vardo
# Processing Record 49 of Set 4 | baranain
# Processing Record 50 of Set 4 | east london
# Processing Record 1 of Set 5 | bilaspur
# Processing Record 2 of Set 5 | iquique
# Processing Record 3 of Set 5 | bahia honda
# Processing Record 4 of Set 5 | kavaratti
# Processing Record 5 of Set 5 | savannah bight
# Processing Record 6 of Set 5 | itacoatiara
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | muros
# Processing Record 9 of Set 5 | san luis
# Processing Record 10 of Set 5 | urla
# Processing Record 11 of Set 5 | itarema
# Processing Record 12 of Set 5 | kahului
# Processing Record 13 of Set 5 | pizarro
# Processing Record 14 of Set 5 | uarini
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | gazojak
# Processing Record 17 of Set 5 | tashla
# Processing Record 18 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 5 | dongying
# Processing Record 20 of Set 5 | ponta do sol
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | nagato
# Processing Record 23 of Set 5 | laguna
# Processing Record 24 of Set 5 | antofagasta
# Processing Record 25 of Set 5 | maku
# Processing Record 26 of Set 5 | pangai
# Processing Record 27 of Set 5 | ilulissat
# Processing Record 28 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 5 | xiamen
# Processing Record 30 of Set 5 | port-gentil
# Processing Record 31 of Set 5 | hienghene
# Processing Record 32 of Set 5 | cockburn town
# Processing Record 33 of Set 5 | khani
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | whitianga
# Processing Record 37 of Set 5 | cornetu
# Processing Record 38 of Set 5 | tiksi
# Processing Record 39 of Set 5 | makakilo city
# Processing Record 40 of Set 5 | mul
# Processing Record 41 of Set 5 | nome
# Processing Record 42 of Set 5 | ucluelet
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | kiunga
# Processing Record 45 of Set 5 | markova
# Processing Record 46 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 5 | anchorage
# Processing Record 48 of Set 5 | apatou
# Processing Record 49 of Set 5 | port macquarie
# Processing Record 50 of Set 5 | castro
# Processing Record 1 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 6 | kizukuri
# Processing Record 3 of Set 6 | bol
# Processing Record 4 of Set 6 | healdsburg
# Processing Record 5 of Set 6 | margate
# Processing Record 6 of Set 6 | pacifica
# Processing Record 7 of Set 6 | te karaka
# Processing Record 8 of Set 6 | fairbanks
# Processing Record 9 of Set 6 | gorontalo
# Processing Record 10 of Set 6 | rundu
# Processing Record 11 of Set 6 | saint-pierre
# Processing Record 12 of Set 6 | agadez
# Processing Record 13 of Set 6 | mazyr
# Processing Record 14 of Set 6 | ukiah
# Processing Record 15 of Set 6 | manono
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | kawalu
# Processing Record 18 of Set 6 | tevaitoa
# Processing Record 19 of Set 6 | san
# Processing Record 20 of Set 6 | umba
# Processing Record 21 of Set 6 | tommot
# Processing Record 22 of Set 6 | mbinga
# Processing Record 23 of Set 6 | port hedland
# Processing Record 24 of Set 6 | seymchan
# Processing Record 25 of Set 6 | asyut
# Processing Record 26 of Set 6 | inta
# Processing Record 27 of Set 6 | mutare
# Processing Record 28 of Set 6 | zhanaozen
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | tuatapere
# Processing Record 31 of Set 6 | necochea
# Processing Record 32 of Set 6 | igrim
# Processing Record 33 of Set 6 | ribeira grande
# Processing Record 34 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 35 of Set 6 | gizo
# Processing Record 36 of Set 6 | bethel
# Processing Record 37 of Set 6 | mayo
# Processing Record 38 of Set 6 | bhandara
# Processing Record 39 of Set 6 | hasaki
# Processing Record 40 of Set 6 | keetmanshoop
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | la gaulette
# City not found. Skipping...
# Processing Record 43 of Set 6 | jardim
# Processing Record 44 of Set 6 | jutai
# Processing Record 45 of Set 6 | constitucion
# Processing Record 46 of Set 6 | segezha
# Processing Record 47 of Set 6 | belinskiy
# Processing Record 48 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | adra
# Processing Record 1 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 7 | bani
# Processing Record 3 of Set 7 | ambilobe
# Processing Record 4 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 7 | zhezkazgan
# Processing Record 6 of Set 7 | rio gallegos
# Processing Record 7 of Set 7 | ambon
# Processing Record 8 of Set 7 | tessalit
# Processing Record 9 of Set 7 | nikolskoye
# Processing Record 10 of Set 7 | meilu
# City not found. Skipping...
# Processing Record 11 of Set 7 | urdoma
# Processing Record 12 of Set 7 | kaeo
# Processing Record 13 of Set 7 | tiarei
# Processing Record 14 of Set 7 | sonoita
# Processing Record 15 of Set 7 | tabuk
# Processing Record 16 of Set 7 | ust-ishim
# Processing Record 17 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 7 | zhigansk
# Processing Record 19 of Set 7 | dickinson
# Processing Record 20 of Set 7 | quesnel
# Processing Record 21 of Set 7 | flin flon
# Processing Record 22 of Set 7 | mount gambier
# Processing Record 23 of Set 7 | eucaliptus
# Processing Record 24 of Set 7 | muli
# Processing Record 25 of Set 7 | tupik
# Processing Record 26 of Set 7 | wukari
# Processing Record 27 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | worland
# Processing Record 29 of Set 7 | soe
# Processing Record 30 of Set 7 | santa helena de goias
# Processing Record 31 of Set 7 | ullapool
# Processing Record 32 of Set 7 | ongandjera
# Processing Record 33 of Set 7 | katobu
# Processing Record 34 of Set 7 | amahai
# Processing Record 35 of Set 7 | san ramon
# Processing Record 36 of Set 7 | nhulunbuy
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | qarchak
# Processing Record 39 of Set 7 | idil
# Processing Record 40 of Set 7 | los llanos de aridane
# Processing Record 41 of Set 7 | diapaga
# Processing Record 42 of Set 7 | altay
# Processing Record 43 of Set 7 | hermon
# Processing Record 44 of Set 7 | las cruces
# Processing Record 45 of Set 7 | tahe
# Processing Record 46 of Set 7 | port lincoln
# Processing Record 47 of Set 7 | comana
# Processing Record 48 of Set 7 | thompson
# Processing Record 49 of Set 7 | aswan
# Processing Record 50 of Set 7 | mkushi
# Processing Record 1 of Set 8 | chapais
# Processing Record 2 of Set 8 | xuddur
# Processing Record 3 of Set 8 | acapulco
# Processing Record 4 of Set 8 | kualakapuas
# Processing Record 5 of Set 8 | bira
# Processing Record 6 of Set 8 | iqaluit
# Processing Record 7 of Set 8 | grindavik
# Processing Record 8 of Set 8 | new castle
# Processing Record 9 of Set 8 | beringovskiy
# Processing Record 10 of Set 8 | northam
# Processing Record 11 of Set 8 | keti bandar
# Processing Record 12 of Set 8 | mulki
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | astoria
# Processing Record 15 of Set 8 | sao joao da barra
# Processing Record 16 of Set 8 | grande prairie
# Processing Record 17 of Set 8 | komsomolsk
# Processing Record 18 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 8 | talcahuano
# Processing Record 20 of Set 8 | manaus
# Processing Record 21 of Set 8 | luanda
# Processing Record 22 of Set 8 | dunedin
# Processing Record 23 of Set 8 | pilao arcado
# City not found. Skipping...
# Processing Record 24 of Set 8 | boende
# Processing Record 25 of Set 8 | buraydah
# Processing Record 26 of Set 8 | ranong
# Processing Record 27 of Set 8 | ganzhou
# Processing Record 28 of Set 8 | starosubkhangulovo
# Processing Record 29 of Set 8 | aquiraz
# Processing Record 30 of Set 8 | campana
# Processing Record 31 of Set 8 | whitehorse
# Processing Record 32 of Set 8 | bengkulu
# Processing Record 33 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 8 | dumas
# Processing Record 35 of Set 8 | asosa
# Processing Record 36 of Set 8 | evensk
# Processing Record 37 of Set 8 | sangar
# Processing Record 38 of Set 8 | taltal
# Processing Record 39 of Set 8 | verkhnyaya inta
# Processing Record 40 of Set 8 | tilichiki
# Processing Record 41 of Set 8 | tatawin
# Processing Record 42 of Set 8 | norman wells
# Processing Record 43 of Set 8 | saurimo
# Processing Record 44 of Set 8 | portobelo
# Processing Record 45 of Set 8 | sirfa
# City not found. Skipping...
# Processing Record 46 of Set 8 | anamur
# Processing Record 47 of Set 8 | lanivtsi
# Processing Record 48 of Set 8 | hervey bay
# Processing Record 49 of Set 8 | kesennuma
# City not found. Skipping...
# Processing Record 50 of Set 8 | praia
# Processing Record 1 of Set 9 | bubaque
# Processing Record 2 of Set 9 | boa esperanca
# Processing Record 3 of Set 9 | tabou
# Processing Record 4 of Set 9 | road town
# Processing Record 5 of Set 9 | sitka
# Processing Record 6 of Set 9 | galle
# Processing Record 7 of Set 9 | burgeo
# Processing Record 8 of Set 9 | darab
# Processing Record 9 of Set 9 | angoche
# Processing Record 10 of Set 9 | tazovskiy
# Processing Record 11 of Set 9 | san patricio
# Processing Record 12 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 9 | kieta
# Processing Record 14 of Set 9 | leninskoye
# Processing Record 15 of Set 9 | bara
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 9 | ahuimanu
# Processing Record 19 of Set 9 | belyy yar
# Processing Record 20 of Set 9 | wladyslawowo
# Processing Record 21 of Set 9 | kholodnyy
# Processing Record 22 of Set 9 | brae
# Processing Record 23 of Set 9 | santa fe
# Processing Record 24 of Set 9 | rio grande
# Processing Record 25 of Set 9 | springdale
# Processing Record 26 of Set 9 | egvekinot
# Processing Record 27 of Set 9 | sambava
# Processing Record 28 of Set 9 | ternate
# Processing Record 29 of Set 9 | guicheng
# City not found. Skipping...
# Processing Record 30 of Set 9 | hay river
# Processing Record 31 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 9 | caticugan
# Processing Record 33 of Set 9 | denpasar
# Processing Record 34 of Set 9 | cabo san lucas
# Processing Record 35 of Set 9 | nara
# Processing Record 36 of Set 9 | oranjemund
# Processing Record 37 of Set 9 | tagusao
# Processing Record 38 of Set 9 | quatre cocos
# Processing Record 39 of Set 9 | aginskoye
# Processing Record 40 of Set 9 | ocampo
# Processing Record 41 of Set 9 | rosetta
# Processing Record 42 of Set 9 | saint paul
# Processing Record 43 of Set 9 | ibbenburen
# Processing Record 44 of Set 9 | santa rosa
# Processing Record 45 of Set 9 | port-cartier
# Processing Record 46 of Set 9 | himora
# City not found. Skipping...
# Processing Record 47 of Set 9 | souillac
# Processing Record 48 of Set 9 | butia
# Processing Record 49 of Set 9 | carmarthen
# Processing Record 50 of Set 9 | zarinsk
# Processing Record 1 of Set 10 | aykhal
# Processing Record 2 of Set 10 | fort nelson
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | sembakung
# Processing Record 5 of Set 10 | chom bung
# City not found. Skipping...
# Processing Record 6 of Set 10 | weyburn
# Processing Record 7 of Set 10 | harper
# Processing Record 8 of Set 10 | provideniya
# Processing Record 9 of Set 10 | alexander city
# Processing Record 10 of Set 10 | murgab
# Processing Record 11 of Set 10 | mar del plata
# Processing Record 12 of Set 10 | sale
# Processing Record 13 of Set 10 | kencong
# Processing Record 14 of Set 10 | chara
# Processing Record 15 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 10 | puerto madryn
# Processing Record 17 of Set 10 | lodingen
# Processing Record 18 of Set 10 | kavieng
# Processing Record 19 of Set 10 | springbok
# Processing Record 20 of Set 10 | jumla
# Processing Record 21 of Set 10 | oudtshoorn
# Processing Record 22 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 10 | dutlwe
# Processing Record 25 of Set 10 | sinnamary
# Processing Record 26 of Set 10 | camaqua
# Processing Record 27 of Set 10 | sisimiut
# Processing Record 28 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 10 | sheopur
# Processing Record 30 of Set 10 | jalu
# Processing Record 31 of Set 10 | yerbogachen
# Processing Record 32 of Set 10 | toguchin
# Processing Record 33 of Set 10 | tabory
# Processing Record 34 of Set 10 | abu samrah
# Processing Record 35 of Set 10 | lixourion
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | west bay
# Processing Record 38 of Set 10 | xalpatlahuac
# Processing Record 39 of Set 10 | koshurnikovo
# Processing Record 40 of Set 10 | namibe
# Processing Record 41 of Set 10 | makubetsu
# Processing Record 42 of Set 10 | yakeshi
# Processing Record 43 of Set 10 | woodburn
# Processing Record 44 of Set 10 | papara
# Processing Record 45 of Set 10 | hobyo
# Processing Record 46 of Set 10 | morant bay
# Processing Record 47 of Set 10 | mogadishu
# Processing Record 48 of Set 10 | pangnirtung
# Processing Record 49 of Set 10 | nikolayevsk-na-amure
# Processing Record 50 of Set 10 | kangra
# Processing Record 1 of Set 11 | paredon
# Processing Record 2 of Set 11 | hede
# Processing Record 3 of Set 11 | ndungu
# Processing Record 4 of Set 11 | lidkoping
# Processing Record 5 of Set 11 | samarai
# Processing Record 6 of Set 11 | port keats
# Processing Record 7 of Set 11 | touros
# Processing Record 8 of Set 11 | dali
# Processing Record 9 of Set 11 | stoholm
# Processing Record 10 of Set 11 | melfi
# Processing Record 11 of Set 11 | husavik
# Processing Record 12 of Set 11 | puerto penasco
# Processing Record 13 of Set 11 | gayeri
# Processing Record 14 of Set 11 | akyab
# Processing Record 15 of Set 11 | copiapo
# Processing Record 16 of Set 11 | madingou
# Processing Record 17 of Set 11 | viransehir
# Processing Record 18 of Set 11 | vikulovo
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | waynesville
# Processing Record 21 of Set 11 | thinadhoo
# Processing Record 22 of Set 11 | carutapera
# Processing Record 23 of Set 11 | kizilskoye
# Processing Record 24 of Set 11 | dakoro
# Processing Record 25 of Set 11 | ocos
# Processing Record 26 of Set 11 | lavrentiya
# Processing Record 27 of Set 11 | gemena
# Processing Record 28 of Set 11 | kirakira
# Processing Record 29 of Set 11 | ayan
# Processing Record 30 of Set 11 | cave spring
# Processing Record 31 of Set 11 | diego de almagro
# Processing Record 32 of Set 11 | bandarbeyla
# Processing Record 33 of Set 11 | aleppo
# Processing Record 34 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 11 | lata
# Processing Record 36 of Set 11 | alenquer
# Processing Record 37 of Set 11 | jepara
# Processing Record 38 of Set 11 | koroni
# Processing Record 39 of Set 11 | mitu
# Processing Record 40 of Set 11 | stettler
# Processing Record 41 of Set 11 | honiara
# Processing Record 42 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 11 | lalsk
# Processing Record 44 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 46 of Set 11 | coihaique
# Processing Record 47 of Set 11 | turukhansk
# Processing Record 48 of Set 11 | filadelfia
# Processing Record 49 of Set 11 | vero beach
# Processing Record 50 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 12 | smithers
# Processing Record 2 of Set 12 | guerrero negro
# Processing Record 3 of Set 12 | waddan
# Processing Record 4 of Set 12 | sola
# Processing Record 5 of Set 12 | xichang
# Processing Record 6 of Set 12 | bloemfontein
# Processing Record 7 of Set 12 | gilgil
# City not found. Skipping...
# Processing Record 8 of Set 12 | lorengau
# Processing Record 9 of Set 12 | tello
# Processing Record 10 of Set 12 | vila franca do campo
# Processing Record 11 of Set 12 | plover
# Processing Record 12 of Set 12 | naze
# Processing Record 13 of Set 12 | saint-francois
# Processing Record 14 of Set 12 | misratah
# Processing Record 15 of Set 12 | atbasar
# Processing Record 16 of Set 12 | burnie
# Processing Record 17 of Set 12 | niquelandia
# Processing Record 18 of Set 12 | novoilinskiy
# City not found. Skipping...
# Processing Record 19 of Set 12 | westport
# Processing Record 20 of Set 12 | chalons-en-champagne
# Processing Record 21 of Set 12 | san javier
# Processing Record 22 of Set 12 | guadalupe y calvo
# Processing Record 23 of Set 12 | polunochnoye
# Processing Record 24 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 12 | quimper
# Processing Record 26 of Set 12 | anage
# Processing Record 27 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 12 | boa vista
# Processing Record 29 of Set 12 | hohhot
# Processing Record 30 of Set 12 | muroto
# Processing Record 31 of Set 12 | grand-lahou
# Processing Record 32 of Set 12 | san matias
# Processing Record 33 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 34 of Set 12 | san andres
# Processing Record 35 of Set 12 | espanola
# Processing Record 36 of Set 12 | stamsund
# City not found. Skipping...
# Processing Record 37 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 38 of Set 12 | adrar
# Processing Record 39 of Set 12 | kloulklubed
# Processing Record 40 of Set 12 | zemio
# Processing Record 41 of Set 12 | soledade
# Processing Record 42 of Set 12 | kayerkan
# Processing Record 43 of Set 12 | sur
# Processing Record 44 of Set 12 | veraval
# Processing Record 45 of Set 12 | tandil
# Processing Record 46 of Set 12 | general roca
# Processing Record 47 of Set 12 | ancud
# Processing Record 48 of Set 12 | gewane
# Processing Record 49 of Set 12 | wahiawa
# Processing Record 50 of Set 12 | kindu
# Processing Record 1 of Set 13 | kapuskasing
# Processing Record 2 of Set 13 | camopi
# Processing Record 3 of Set 13 | carbonia
# Processing Record 4 of Set 13 | karoi
# Processing Record 5 of Set 13 | kununurra
# Processing Record 6 of Set 13 | baruun-urt
# Processing Record 7 of Set 13 | kangaatsiaq
# Processing Record 8 of Set 13 | zhenjiang
# Processing Record 9 of Set 13 | basoko
# Processing Record 10 of Set 13 | poya
# Processing Record 11 of Set 13 | camacha
# Processing Record 12 of Set 13 | villafranca de los barros
# Processing Record 13 of Set 13 | san cristobal
# Processing Record 14 of Set 13 | indian head
# Processing Record 15 of Set 13 | yarmouth
# Processing Record 16 of Set 13 | nusaybin
# Processing Record 17 of Set 13 | olinda
# Processing Record 18 of Set 13 | dzaoudzi
# Processing Record 19 of Set 13 | ypsonas
# Processing Record 20 of Set 13 | maneadero
# Processing Record 21 of Set 13 | amapa
# Processing Record 22 of Set 13 | shizunai
# Processing Record 23 of Set 13 | dalbandin
# Processing Record 24 of Set 13 | washougal
# Processing Record 25 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 13 | novo aripuana
# Processing Record 27 of Set 13 | deputatskiy
# Processing Record 28 of Set 13 | maridi
# Processing Record 29 of Set 13 | abeche
# Processing Record 30 of Set 13 | rincon
# Processing Record 31 of Set 13 | sines
# Processing Record 32 of Set 13 | ixtapa
# Processing Record 33 of Set 13 | balsas
# Processing Record 34 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 13 | opuwo
# Processing Record 36 of Set 13 | tchibanga
# Processing Record 37 of Set 13 | yagodnoye
# Processing Record 38 of Set 13 | tonstad
# Processing Record 39 of Set 13 | tandalti
# Processing Record 40 of Set 13 | benalla
# Processing Record 41 of Set 13 | lazaro cardenas
# Processing Record 42 of Set 13 | nogliki
# Processing Record 43 of Set 13 | gotsu
# Processing Record 44 of Set 13 | morro bay
# Processing Record 45 of Set 13 | half moon bay
# Processing Record 46 of Set 13 | southbridge
# Processing Record 47 of Set 13 | homer
# Processing Record 48 of Set 13 | masterton
# Processing Record 49 of Set 13 | mbandaka
# Processing Record 50 of Set 13 | sweetwater
# Processing Record 1 of Set 14 | thap than
# Processing Record 2 of Set 14 | griffith
# Processing Record 3 of Set 14 | pacific grove
# Processing Record 4 of Set 14 | mukhen
# Processing Record 5 of Set 14 | lima
# Processing Record 6 of Set 14 | ust-nera
# Processing Record 7 of Set 14 | chunhuhub
# Processing Record 8 of Set 14 | kendari
# Processing Record 9 of Set 14 | salalah
# Processing Record 10 of Set 14 | paamiut
# Processing Record 11 of Set 14 | bridlington
# Processing Record 12 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 13 of Set 14 | soskovo
# Processing Record 14 of Set 14 | ribeira brava
# Processing Record 15 of Set 14 | snezhnogorsk
# Processing Record 16 of Set 14 | kansanshi
# Processing Record 17 of Set 14 | orsk
# Processing Record 18 of Set 14 | sibolga
# Processing Record 19 of Set 14 | athens
# Processing Record 20 of Set 14 | amga
# Processing Record 21 of Set 14 | yeppoon
# Processing Record 22 of Set 14 | strezhevoy
# Processing Record 23 of Set 14 | liverpool
# Processing Record 24 of Set 14 | scarborough
# Processing Record 25 of Set 14 | hermiston
# Processing Record 26 of Set 14 | sakakah
# Processing Record 27 of Set 14 | iskateley
# Processing Record 28 of Set 14 | palmer
# Processing Record 29 of Set 14 | ritchie
# Processing Record 30 of Set 14 | grootfontein
# Processing Record 31 of Set 14 | zhangjiakou
# Processing Record 32 of Set 14 | barcelos
# Processing Record 33 of Set 14 | fukuma
# Processing Record 34 of Set 14 | esperance
# Processing Record 35 of Set 14 | zhuhai
# Processing Record 36 of Set 14 | abalak
# Processing Record 37 of Set 14 | estevan
# Processing Record 38 of Set 14 | nakusp
# Processing Record 39 of Set 14 | tautira
# Processing Record 40 of Set 14 | rapid valley
# Processing Record 41 of Set 14 | sabha
# Processing Record 42 of Set 14 | shimoda
# Processing Record 43 of Set 14 | oga
# Processing Record 44 of Set 14 | rocha
# Processing Record 45 of Set 14 | batagay-alyta
# Processing Record 46 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 47 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 48 of Set 14 | kuhdasht
# Processing Record 49 of Set 14 | porto belo
# Processing Record 50 of Set 14 | fort-shevchenko
# Processing Record 1 of Set 15 | ejura
# Processing Record 2 of Set 15 | vanimo
# Processing Record 3 of Set 15 | nizhneudinsk
# Processing Record 4 of Set 15 | valleyview
# Processing Record 5 of Set 15 | golkoy
# Processing Record 6 of Set 15 | warrington
# Processing Record 7 of Set 15 | bailieborough
# Processing Record 8 of Set 15 | davila
# Processing Record 9 of Set 15 | katangli
# Processing Record 10 of Set 15 | mangan
# Processing Record 11 of Set 15 | ishigaki
# Processing Record 12 of Set 15 | sherman
# Processing Record 13 of Set 15 | ulladulla
# Processing Record 14 of Set 15 | mersing
# Processing Record 15 of Set 15 | borujan
# City not found. Skipping...
# Processing Record 16 of Set 15 | talara
# Processing Record 17 of Set 15 | zhanakorgan
# Processing Record 18 of Set 15 | svetlogorsk
# Processing Record 19 of Set 15 | chimbote
# Processing Record 20 of Set 15 | gorgan
# Processing Record 21 of Set 15 | teterow
# Processing Record 22 of Set 15 | portree
# Processing Record 23 of Set 15 | inhambane
# Processing Record 24 of Set 15 | maraa
# Processing Record 25 of Set 15 | caravelas
# Processing Record 26 of Set 15 | himeji
# Processing Record 27 of Set 15 | ati
# Processing Record 28 of Set 15 | manggar
# Processing Record 29 of Set 15 | rodrigues alves
# Processing Record 30 of Set 15 | chake chake
# Processing Record 31 of Set 15 | nador
# Processing Record 32 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 33 of Set 15 | la ronge
# Processing Record 34 of Set 15 | yerofey pavlovich
# Processing Record 35 of Set 15 | noumea
# Processing Record 36 of Set 15 | traralgon
# Processing Record 37 of Set 15 | oktyabrskiy
# Processing Record 38 of Set 15 | kisangani
# Processing Record 39 of Set 15 | oktyabrskoye
# Processing Record 40 of Set 15 | kaya
# Processing Record 41 of Set 15 | vila do maio
# Processing Record 42 of Set 15 | fairfield
# Processing Record 43 of Set 15 | finschhafen
# Processing Record 44 of Set 15 | nemuro
# Processing Record 45 of Set 15 | notre-dame-du-lac
# Processing Record 46 of Set 15 | pumiao
# Processing Record 47 of Set 15 | terney
# Processing Record 48 of Set 15 | enshi
# Processing Record 49 of Set 15 | atkinson
# Processing Record 50 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 1 of Set 16 | barroualie
# City not found. Skipping...
# Processing Record 2 of Set 16 | kibala
# Processing Record 3 of Set 16 | te anau
# Processing Record 4 of Set 16 | perelyub
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mahebourg      MU -20.4081   57.7000     75.25        94          20
# 1        Hope      US  33.6671  -93.5916     86.99        74           2
# 2     Ushuaia      AR -54.8000  -68.3000     40.66        75           0
# 3   Norrtalje      SE  59.7580   18.7050     50.18        93         100
# 4   Carnarvon      AU -24.8667  113.6333     69.87        94          94
# 5      Marawi      PH   7.9986  124.2928     75.38        83          96
# 6      Nyurba      RU  63.2842  118.3319     39.36        71          41
# 7  Nouadhibou      MR  20.9310  -17.0347     66.72        82          95
# 8     Batagay      RU  67.6333  134.6333     22.15        67          69
# 9    Hamilton      US  39.1834  -84.5333     81.23        65          40
#
#    Wind Speed Current Description
# 0        4.61          few clouds
# 1        3.91           clear sky
# 2        5.75           clear sky
# 3       12.44          light rain
# 4        0.00     overcast clouds
# 5        1.19     overcast clouds
# 6        5.19    scattered clouds
# 7       13.04     overcast clouds
# 8        4.97       broken clouds
# 9        4.61    scattered clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
