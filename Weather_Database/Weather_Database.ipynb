# %%
# Import dependencies and the api key

import pandas as pd
import numpy as np
import json 
import requests
from citipy import citipy
import timeit


from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. Because we only need to create a set of random latitudes and longitudes one time

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list and check it

coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(23.675611380396973, 114.92556562343736), (-12.5021888048513, 11.377054565607295), (-4.5049050507283255, 9.507341424583927), (-23.453183591441373, 20.7823685208713), (4.561316322450821, 36.79852025751373), (15.4029895745538, -108.59404439363955), (67.50969608061132, -38.68809799019837), (-32.95803026634502, -151.69430234280355), (26.429299972584246, -49.248737905290284), (-52.495846650904426, -111.30935587034766), (-1.8772372552937782, 174.9451328817771), (78.16898396016975, 86.4380148271685), (63.42369789769026, 23.377229050321176), (25.50862074152299, -92.95015722440468), (-82.33733499641572, -72.57546073796678), (-47.41387023872494, -157.89009577345604), (-16.93788953623732, -160.91712419601117), (46.92000674431307, -110.79367720346951), (5.608880099251223, 8.425912366339986), (45.031768196689114, 140.62846090213276), (84.96381168973983, 58.58569521030009), (21.864366753764514, -177.64694728948876), (6.969602947517885, 154.3829305822086), (-77.07185630590585, -159.55360997845204), (-25.070612715449926, -166.52404622238745), (-21.754027558698056, 17.523269322886193), (-4.643177634761727, 179.31733904756305), (-46.05541573442734, 21.620542343999944), (-10.178413122698515, -7.751496708412191), (29.89656304654747, -28.532955721790103), (-80.78236635051836, -171.73117173426863), (-34.563266625720296, 109.2823824005157), (30.50861731408493, -144.5307841137307), (-64.39651828464575, 95.06771385112239), (37.08649926395185, -90.05954662818966), (8.653671118310257, 150.3112742877832), (-68.01431919062969, -175.63619572504476), (0.2595193195489003, -19.42984134973338), (-12.793553832494297, 46.900205667700675), (-1.4298012197851335, -105.7209489795455), (-44.82644643051681, -112.94584784921747), (85.39397826183514, -168.69589050497527), (4.716749484830558, 136.92597752210168), (72.11924497627979, -82.5696216920948), (-23.61524844812628, -90.79082044676119), (-45.38809443003407, 57.83027070665864), (-71.3961013724871, 27.20952251439158), (-46.03752434656209, 97.79892637920125), (-1.113331353807169, 117.92872946594343), (29.466282928446205, 107.74780904513204), (-25.787884037343886, -127.88492924744341), (11.968001889970225, 93.63022072620265), (54.8641391130258, -177.26642134643106), (60.91479976620204, 77.6962548566612), (17.405423866676756, 131.62526151322288), (-57.027786922972076, -104.96734937820817), (52.72199819609267, 132.8721987417992), (-58.29797464018816, 104.46879887688766), (71.00269566183542, 0.35777227318868654), (19.03541503033408, -127.12695852383547), (13.261863603594321, 76.76098960683765), (-70.89635789857135, -77.6011074842857), (24.046799759033334, -128.61822976754942), (46.30149203629162, 32.00609963423602), (61.77167602544509, -137.5998923949653), (4.404863820302822, 82.79896183714277), (-80.48721353284905, -67.19260045353788), (-57.37038081355311, 133.17017598475428), (61.68411950859473, -99.23212870914404), (-22.0340330266729, -41.29660173769673), (-44.64309259242475, 49.54655859274638), (87.80500936068461, 4.163656985449734), (-17.11461071405482, -92.92968729920884), (-89.53577758869639, -69.56625737249334), (-85.78707261368798, -174.0586752082181), (-23.068719950644578, -9.170098442630774), (51.300135359867454, -134.9018113417063), (-75.61718427169163, -78.2123129754623), (-0.26155577832952304, 125.62113028177913), (-87.72110669473994, -148.37863146791503), (10.459022335245692, -173.49732907661243), (-18.32363108545151, 8.111116075252994), (-15.185117346219002, 75.99704999010149), (64.13101138551195, -13.618399486782465), (-87.21671306460907, -176.23463205220222), (49.73214068895308, 62.654390507144), (32.99738617360204, 69.03784005027973), (41.61996418970696, -35.9386523937184), (22.695695509215312, 167.2804112457227), (39.47072448836036, 24.381243527991415), (67.1645376553102, -125.93070379533039), (-29.105291066366497, -1.3557461085829345), (-39.110659802254034, 126.4018567074109), (64.02187988773343, -125.64288167852591), (19.259963429651094, -60.33020142833), (47.70626413726268, -43.795914557382446), ( ...

# %%
# Get the nearest city using the citipy module and create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Starting URL for Weather Map API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3eb5db8564aa00e965bac3a34dfb2af2

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yuancheng
# Processing Record 2 of Set 1 | benguela
# Processing Record 3 of Set 1 | mayumba
# Processing Record 4 of Set 1 | manyana
# Processing Record 5 of Set 1 | jinka
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | codrington
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | kokkola
# Processing Record 14 of Set 1 | freeport
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | great falls
# Processing Record 18 of Set 1 | ugep
# Processing Record 19 of Set 1 | wakkanai
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | kavieng
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | okahandja
# Processing Record 25 of Set 1 | asau
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | ponta delgada
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | poplar bluff
# Processing Record 33 of Set 1 | lorengau
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | dzaoudzi
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | kloulklubed
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | pisco
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | samarinda
# Processing Record 44 of Set 1 | fuling
# Processing Record 45 of Set 1 | port blair
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | strezhevoy
# Processing Record 48 of Set 1 | alugan
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | koboldo
# City not found. Skipping...
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | raudeberg
# Processing Record 3 of Set 2 | guerrero negro
# Processing Record 4 of Set 2 | turuvekere
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | bekhtery
# Processing Record 7 of Set 2 | haines junction
# Processing Record 8 of Set 2 | hambantota
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | campos
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | huarmey
# Processing Record 15 of Set 2 | ketchikan
# Processing Record 16 of Set 2 | tondano
# Processing Record 17 of Set 2 | namibe
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | hofn
# Processing Record 20 of Set 2 | svetlyy
# Processing Record 21 of Set 2 | orgun
# City not found. Skipping...
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | skiros
# City not found. Skipping...
# Processing Record 25 of Set 2 | norman wells
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | matagami
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | soyo
# Processing Record 31 of Set 2 | bud
# Processing Record 32 of Set 2 | tokur
# Processing Record 33 of Set 2 | caravelas
# Processing Record 34 of Set 2 | tefe
# Processing Record 35 of Set 2 | slyudyanka
# Processing Record 36 of Set 2 | coihaique
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | urumqi
# Processing Record 39 of Set 2 | jeremoabo
# Processing Record 40 of Set 2 | kununurra
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | mendi
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | sibolga
# Processing Record 47 of Set 2 | desnogorsk
# Processing Record 48 of Set 2 | east wenatchee bench
# Processing Record 49 of Set 2 | hailey
# Processing Record 50 of Set 2 | bathsheba
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | kinkala
# Processing Record 4 of Set 3 | sovetskaya
# Processing Record 5 of Set 3 | mehamn
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | ratnagiri
# Processing Record 8 of Set 3 | bengkulu
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 3 | coolum beach
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | stromness
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | ancud
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | santa maria
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | tateyama
# Processing Record 25 of Set 3 | tanshui
# City not found. Skipping...
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 3 | cap malheureux
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | eltham
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | henties bay
# Processing Record 36 of Set 3 | trinidad
# Processing Record 37 of Set 3 | ulaanbaatar
# Processing Record 38 of Set 3 | puerto parra
# Processing Record 39 of Set 3 | loyga
# Processing Record 40 of Set 3 | carutapera
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | borama
# City not found. Skipping...
# Processing Record 44 of Set 3 | hobart
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | katsuura
# Processing Record 48 of Set 3 | chapada dos guimaraes
# Processing Record 49 of Set 3 | summerside
# Processing Record 50 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 4 | lagoa
# Processing Record 2 of Set 4 | helmsdale
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 4 | vao
# Processing Record 6 of Set 4 | farafangana
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | yanam
# Processing Record 9 of Set 4 | kolda
# Processing Record 10 of Set 4 | ust-omchug
# Processing Record 11 of Set 4 | hostotipaquillo
# Processing Record 12 of Set 4 | abu kamal
# Processing Record 13 of Set 4 | ginda
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | cotacachi
# Processing Record 16 of Set 4 | mumbwa
# Processing Record 17 of Set 4 | vanimo
# Processing Record 18 of Set 4 | krasnoselkup
# Processing Record 19 of Set 4 | kayes
# Processing Record 20 of Set 4 | port alfred
# Processing Record 21 of Set 4 | broken hill
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | suleja
# Processing Record 24 of Set 4 | keti bandar
# Processing Record 25 of Set 4 | te anau
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | pucara
# Processing Record 28 of Set 4 | rocha
# Processing Record 29 of Set 4 | flin flon
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | luwingu
# Processing Record 33 of Set 4 | guadalupe victoria
# Processing Record 34 of Set 4 | hasaki
# Processing Record 35 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 4 | clovis
# Processing Record 37 of Set 4 | san quintin
# Processing Record 38 of Set 4 | kano
# Processing Record 39 of Set 4 | port hedland
# Processing Record 40 of Set 4 | potsdam
# Processing Record 41 of Set 4 | foumban
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | ravar
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 46 of Set 4 | margate
# Processing Record 47 of Set 4 | fairbanks
# Processing Record 48 of Set 4 | padang
# Processing Record 49 of Set 4 | sherlovaya gora
# Processing Record 50 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 5 | baie-comeau
# Processing Record 2 of Set 5 | kwinana
# Processing Record 3 of Set 5 | igarka
# Processing Record 4 of Set 5 | fomboni
# Processing Record 5 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 5 | arlit
# Processing Record 7 of Set 5 | les cayes
# Processing Record 8 of Set 5 | ayagoz
# Processing Record 9 of Set 5 | shimoda
# Processing Record 10 of Set 5 | champerico
# Processing Record 11 of Set 5 | bandarbeyla
# Processing Record 12 of Set 5 | phan thiet
# Processing Record 13 of Set 5 | pyapon
# Processing Record 14 of Set 5 | pingliang
# Processing Record 15 of Set 5 | taksimo
# Processing Record 16 of Set 5 | karakulino
# Processing Record 17 of Set 5 | ewa beach
# Processing Record 18 of Set 5 | camacha
# Processing Record 19 of Set 5 | hesperia
# Processing Record 20 of Set 5 | san vicente
# Processing Record 21 of Set 5 | tselinnoye
# Processing Record 22 of Set 5 | gat
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | saint george
# Processing Record 25 of Set 5 | deputatskiy
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | livramento
# Processing Record 28 of Set 5 | mahebourg
# Processing Record 29 of Set 5 | touba
# Processing Record 30 of Set 5 | vila
# Processing Record 31 of Set 5 | meadow lake
# Processing Record 32 of Set 5 | sorong
# Processing Record 33 of Set 5 | olinda
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | parabel
# Processing Record 37 of Set 5 | vyartsilya
# Processing Record 38 of Set 5 | atar
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | edson
# Processing Record 41 of Set 5 | belmonte
# Processing Record 42 of Set 5 | grand gaube
# Processing Record 43 of Set 5 | korostyshiv
# Processing Record 44 of Set 5 | sabha
# Processing Record 45 of Set 5 | sungaipenuh
# Processing Record 46 of Set 5 | tricase
# Processing Record 47 of Set 5 | kalmunai
# Processing Record 48 of Set 5 | mozarlandia
# Processing Record 49 of Set 5 | scarborough
# Processing Record 50 of Set 5 | duzici
# City not found. Skipping...
# Processing Record 1 of Set 6 | rawah
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | mecca
# Processing Record 4 of Set 6 | taywarah
# Processing Record 5 of Set 6 | rawson
# Processing Record 6 of Set 6 | sitka
# Processing Record 7 of Set 6 | briceni
# Processing Record 8 of Set 6 | hervey bay
# Processing Record 9 of Set 6 | clinton
# Processing Record 10 of Set 6 | cradock
# Processing Record 11 of Set 6 | niceville
# Processing Record 12 of Set 6 | mangan
# Processing Record 13 of Set 6 | marsa matruh
# Processing Record 14 of Set 6 | senneterre
# Processing Record 15 of Set 6 | westport
# Processing Record 16 of Set 6 | peru
# Processing Record 17 of Set 6 | vila velha
# Processing Record 18 of Set 6 | gongzhuling
# Processing Record 19 of Set 6 | sohag
# Processing Record 20 of Set 6 | pedernales
# Processing Record 21 of Set 6 | belaya gora
# Processing Record 22 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 6 | strelka
# Processing Record 24 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 6 | gibsons
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | iracoubo
# Processing Record 28 of Set 6 | pacific grove
# Processing Record 29 of Set 6 | rovinj
# Processing Record 30 of Set 6 | samarai
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | kaeo
# Processing Record 33 of Set 6 | larsnes
# Processing Record 34 of Set 6 | longyearbyen
# Processing Record 35 of Set 6 | shingu
# Processing Record 36 of Set 6 | moji-mirim
# City not found. Skipping...
# Processing Record 37 of Set 6 | la ronge
# Processing Record 38 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 6 | puerto del rosario
# Processing Record 40 of Set 6 | sobolevo
# Processing Record 41 of Set 6 | asaka
# Processing Record 42 of Set 6 | zaysan
# Processing Record 43 of Set 6 | ugoofaaru
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | pueblo nuevo
# Processing Record 46 of Set 6 | harper
# Processing Record 47 of Set 6 | nemuro
# Processing Record 48 of Set 6 | coari
# Processing Record 49 of Set 6 | yar-sale
# Processing Record 50 of Set 6 | ponta do sol
# Processing Record 1 of Set 7 | yerbogachen
# Processing Record 2 of Set 7 | port-gentil
# Processing Record 3 of Set 7 | paraiso
# Processing Record 4 of Set 7 | derzhavinsk
# Processing Record 5 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 7 | luena
# Processing Record 8 of Set 7 | oranjemund
# Processing Record 9 of Set 7 | pangai
# Processing Record 10 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 7 | ballina
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 14 of Set 7 | lincoln
# Processing Record 15 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 16 of Set 7 | jacareacanga
# Processing Record 17 of Set 7 | marienburg
# Processing Record 18 of Set 7 | yulara
# Processing Record 19 of Set 7 | fallon
# Processing Record 20 of Set 7 | taft
# Processing Record 21 of Set 7 | alta floresta
# Processing Record 22 of Set 7 | kodiak
# Processing Record 23 of Set 7 | santa cruz
# Processing Record 24 of Set 7 | narsaq
# Processing Record 25 of Set 7 | castanos
# Processing Record 26 of Set 7 | hondo
# Processing Record 27 of Set 7 | saint-francois
# Processing Record 28 of Set 7 | tabuk
# Processing Record 29 of Set 7 | araouane
# Processing Record 30 of Set 7 | rehoboth
# Processing Record 31 of Set 7 | parambu
# Processing Record 32 of Set 7 | moron
# Processing Record 33 of Set 7 | porosozero
# Processing Record 34 of Set 7 | gushikawa
# Processing Record 35 of Set 7 | ismailia
# Processing Record 36 of Set 7 | pedra branca
# Processing Record 37 of Set 7 | mossendjo
# Processing Record 38 of Set 7 | gondanglegi
# Processing Record 39 of Set 7 | barinas
# Processing Record 40 of Set 7 | turayf
# Processing Record 41 of Set 7 | bar harbor
# Processing Record 42 of Set 7 | dandong
# Processing Record 43 of Set 7 | sao gabriel da cachoeira
# Processing Record 44 of Set 7 | pevek
# Processing Record 45 of Set 7 | san isidro
# Processing Record 46 of Set 7 | madang
# Processing Record 47 of Set 7 | neiafu
# Processing Record 48 of Set 7 | neon monastirion
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | guerrero
# Processing Record 1 of Set 8 | esna
# Processing Record 2 of Set 8 | pandan
# Processing Record 3 of Set 8 | tura
# Processing Record 4 of Set 8 | young
# Processing Record 5 of Set 8 | tual
# Processing Record 6 of Set 8 | keuruu
# Processing Record 7 of Set 8 | leningradskiy
# Processing Record 8 of Set 8 | shetpe
# Processing Record 9 of Set 8 | ayer itam
# City not found. Skipping...
# Processing Record 10 of Set 8 | lata
# Processing Record 11 of Set 8 | zapolyarnyy
# Processing Record 12 of Set 8 | wad madani
# Processing Record 13 of Set 8 | otradnoye
# Processing Record 14 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 8 | crotone
# Processing Record 16 of Set 8 | khani
# Processing Record 17 of Set 8 | san luis
# Processing Record 18 of Set 8 | marsh harbour
# Processing Record 19 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 20 of Set 8 | aswan
# Processing Record 21 of Set 8 | tommot
# Processing Record 22 of Set 8 | ndele
# Processing Record 23 of Set 8 | taoudenni
# Processing Record 24 of Set 8 | tilichiki
# Processing Record 25 of Set 8 | airai
# Processing Record 26 of Set 8 | killybegs
# Processing Record 27 of Set 8 | najran
# Processing Record 28 of Set 8 | wynyard
# Processing Record 29 of Set 8 | ouallam
# Processing Record 30 of Set 8 | talnakh
# Processing Record 31 of Set 8 | togur
# Processing Record 32 of Set 8 | tuatapere
# Processing Record 33 of Set 8 | nalut
# Processing Record 34 of Set 8 | faya
# Processing Record 35 of Set 8 | verkh-usugli
# Processing Record 36 of Set 8 | lazaro cardenas
# Processing Record 37 of Set 8 | marzuq
# Processing Record 38 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 8 | basco
# Processing Record 40 of Set 8 | bayaguana
# Processing Record 41 of Set 8 | slonim
# Processing Record 42 of Set 8 | falciu
# Processing Record 43 of Set 8 | iqaluit
# Processing Record 44 of Set 8 | kaitangata
# Processing Record 45 of Set 8 | christiana
# Processing Record 46 of Set 8 | sabirabad
# Processing Record 47 of Set 8 | bandar-e lengeh
# Processing Record 48 of Set 8 | los llanos de aridane
# Processing Record 49 of Set 8 | arman
# Processing Record 50 of Set 8 | sao teotonio
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | jutai
# Processing Record 3 of Set 9 | korla
# Processing Record 4 of Set 9 | ogulin
# Processing Record 5 of Set 9 | constitucion
# Processing Record 6 of Set 9 | dongsheng
# Processing Record 7 of Set 9 | warrenton
# Processing Record 8 of Set 9 | massaguet
# Processing Record 9 of Set 9 | bonfim
# Processing Record 10 of Set 9 | mvuma
# Processing Record 11 of Set 9 | hobyo
# Processing Record 12 of Set 9 | vakhrushi
# Processing Record 13 of Set 9 | bara
# Processing Record 14 of Set 9 | paytug
# City not found. Skipping...
# Processing Record 15 of Set 9 | kalemie
# Processing Record 16 of Set 9 | poum
# Processing Record 17 of Set 9 | kavaratti
# Processing Record 18 of Set 9 | vizinga
# Processing Record 19 of Set 9 | eyl
# Processing Record 20 of Set 9 | nome
# Processing Record 21 of Set 9 | yarada
# Processing Record 22 of Set 9 | saint-pierre
# Processing Record 23 of Set 9 | sao goncalo do sapucai
# Processing Record 24 of Set 9 | boyolangu
# Processing Record 25 of Set 9 | axim
# Processing Record 26 of Set 9 | taree
# Processing Record 27 of Set 9 | outlook
# Processing Record 28 of Set 9 | karapyshi
# Processing Record 29 of Set 9 | wairoa
# Processing Record 30 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 9 | touros
# Processing Record 32 of Set 9 | dickinson
# Processing Record 33 of Set 9 | maldonado
# Processing Record 34 of Set 9 | itarema
# Processing Record 35 of Set 9 | lishui
# Processing Record 36 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 38 of Set 9 | saint anthony
# Processing Record 39 of Set 9 | voyvozh
# Processing Record 40 of Set 9 | wajima
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | ixtapa
# Processing Record 43 of Set 9 | keningau
# Processing Record 44 of Set 9 | kawhia
# Processing Record 45 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 9 | turukhansk
# Processing Record 47 of Set 9 | half moon bay
# Processing Record 48 of Set 9 | tamandare
# Processing Record 49 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 50 of Set 9 | batticaloa
# Processing Record 1 of Set 10 | zaragoza
# Processing Record 2 of Set 10 | isangel
# Processing Record 3 of Set 10 | bambanglipuro
# Processing Record 4 of Set 10 | natal
# Processing Record 5 of Set 10 | bonavista
# Processing Record 6 of Set 10 | omboue
# Processing Record 7 of Set 10 | okhotsk
# Processing Record 8 of Set 10 | comodoro rivadavia
# Processing Record 9 of Set 10 | tadine
# Processing Record 10 of Set 10 | hargeysa
# Processing Record 11 of Set 10 | atexcatzingo
# Processing Record 12 of Set 10 | port shepstone
# Processing Record 13 of Set 10 | laguna
# Processing Record 14 of Set 10 | kaseda
# Processing Record 15 of Set 10 | alenquer
# Processing Record 16 of Set 10 | muromtsevo
# Processing Record 17 of Set 10 | gloucester
# Processing Record 18 of Set 10 | pitkyaranta
# Processing Record 19 of Set 10 | pampa
# Processing Record 20 of Set 10 | karmala
# Processing Record 21 of Set 10 | fare
# Processing Record 22 of Set 10 | panzhihua
# Processing Record 23 of Set 10 | noumea
# Processing Record 24 of Set 10 | trairi
# Processing Record 25 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 10 | kultuk
# Processing Record 27 of Set 10 | namatanai
# Processing Record 28 of Set 10 | dennis
# Processing Record 29 of Set 10 | pontianak
# Processing Record 30 of Set 10 | glace bay
# Processing Record 31 of Set 10 | rabo de peixe
# Processing Record 32 of Set 10 | rakke
# Processing Record 33 of Set 10 | juba
# Processing Record 34 of Set 10 | santa isabel
# Processing Record 35 of Set 10 | solano
# Processing Record 36 of Set 10 | ombessa
# Processing Record 37 of Set 10 | kamenka
# Processing Record 38 of Set 10 | barraute
# Processing Record 39 of Set 10 | cayenne
# Processing Record 40 of Set 10 | mogadishu
# Processing Record 41 of Set 10 | tucumcari
# Processing Record 42 of Set 10 | la rioja
# Processing Record 43 of Set 10 | kargasok
# Processing Record 44 of Set 10 | rincon
# Processing Record 45 of Set 10 | port hardy
# Processing Record 46 of Set 10 | donji vakuf
# Processing Record 47 of Set 10 | dori
# Processing Record 48 of Set 10 | masuguru
# Processing Record 49 of Set 10 | ambovombe
# Processing Record 50 of Set 10 | bairiki
# Processing Record 1 of Set 11 | montelimar
# Processing Record 2 of Set 11 | yangjiang
# Processing Record 3 of Set 11 | sarangani
# Processing Record 4 of Set 11 | lubao
# Processing Record 5 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 6 of Set 11 | ambilobe
# Processing Record 7 of Set 11 | alekseyevka
# Processing Record 8 of Set 11 | garissa
# Processing Record 9 of Set 11 | ligayan
# Processing Record 10 of Set 11 | okha
# Processing Record 11 of Set 11 | smithers
# Processing Record 12 of Set 11 | malangali
# Processing Record 13 of Set 11 | necochea
# Processing Record 14 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 11 | markova
# Processing Record 16 of Set 11 | chimbote
# Processing Record 17 of Set 11 | klichka
# Processing Record 18 of Set 11 | kampot
# Processing Record 19 of Set 11 | capitao poco
# Processing Record 20 of Set 11 | kabare
# Processing Record 21 of Set 11 | bisira
# Processing Record 22 of Set 11 | maniitsoq
# Processing Record 23 of Set 11 | road town
# Processing Record 24 of Set 11 | borba
# Processing Record 25 of Set 11 | faanui
# Processing Record 26 of Set 11 | hualmay
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | lowestoft
# Processing Record 29 of Set 11 | san javier
# Processing Record 30 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 11 | riviere-au-renard
# Processing Record 32 of Set 11 | tiarei
# Processing Record 33 of Set 11 | savinka
# Processing Record 34 of Set 11 | sola
# Processing Record 35 of Set 11 | srednekolymsk
# Processing Record 36 of Set 11 | dharchula
# Processing Record 37 of Set 11 | miri
# Processing Record 38 of Set 11 | carballo
# Processing Record 39 of Set 11 | port macquarie
# Processing Record 40 of Set 11 | uaua
# Processing Record 41 of Set 11 | avera
# Processing Record 42 of Set 11 | wangqing
# Processing Record 43 of Set 11 | rio grande city
# Processing Record 44 of Set 11 | peleduy
# Processing Record 45 of Set 11 | nueve de julio
# Processing Record 46 of Set 11 | weligama
# Processing Record 47 of Set 11 | bonnyville
# Processing Record 48 of Set 11 | nuuk
# Processing Record 49 of Set 11 | skjervoy
# Processing Record 50 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 12 | san jose
# Processing Record 2 of Set 12 | oranjestad
# Processing Record 3 of Set 12 | vallenar
# Processing Record 4 of Set 12 | takoradi
# Processing Record 5 of Set 12 | pangoa
# Processing Record 6 of Set 12 | cabo san lucas
# Processing Record 7 of Set 12 | kosikha
# Processing Record 8 of Set 12 | brae
# Processing Record 9 of Set 12 | caririacu
# Processing Record 10 of Set 12 | zomin
# Processing Record 11 of Set 12 | baykit
# Processing Record 12 of Set 12 | samba
# Processing Record 13 of Set 12 | honiara
# Processing Record 14 of Set 12 | roma
# Processing Record 15 of Set 12 | twentynine palms
# Processing Record 16 of Set 12 | mana
# Processing Record 17 of Set 12 | walvis bay
# Processing Record 18 of Set 12 | coquimbo
# Processing Record 19 of Set 12 | pilar
# Processing Record 20 of Set 12 | grand-santi
# Processing Record 21 of Set 12 | high level
# Processing Record 22 of Set 12 | monroe
# Processing Record 23 of Set 12 | suba
# Processing Record 24 of Set 12 | roald
# Processing Record 25 of Set 12 | bozuyuk
# Processing Record 26 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 12 | dingle
# Processing Record 28 of Set 12 | riyadh
# Processing Record 29 of Set 12 | porto velho
# Processing Record 30 of Set 12 | hauterive
# Processing Record 31 of Set 12 | ciudad bolivar
# Processing Record 32 of Set 12 | marsaxlokk
# Processing Record 33 of Set 12 | vila franca do campo
# Processing Record 34 of Set 12 | kokstad
# Processing Record 35 of Set 12 | praya
# Processing Record 36 of Set 12 | craigieburn
# Processing Record 37 of Set 12 | mbandaka
# Processing Record 38 of Set 12 | ziro
# Processing Record 39 of Set 12 | makakilo city
# Processing Record 40 of Set 12 | anadyr
# Processing Record 41 of Set 12 | kashan
# Processing Record 42 of Set 12 | kahului
# Processing Record 43 of Set 12 | hailar
# Processing Record 44 of Set 12 | redlands
# Processing Record 45 of Set 12 | capoterra
# Processing Record 46 of Set 12 | ostrovnoy
# Processing Record 47 of Set 12 | ca mau
# Processing Record 48 of Set 12 | gamba
# Processing Record 49 of Set 12 | kismayo
# Processing Record 50 of Set 12 | quelimane
# Processing Record 1 of Set 13 | usinsk
# Processing Record 2 of Set 13 | zyryanka
# Processing Record 3 of Set 13 | sambava
# Processing Record 4 of Set 13 | severnoye
# Processing Record 5 of Set 13 | husavik
# Processing Record 6 of Set 13 | kutum
# Processing Record 7 of Set 13 | ust-nera
# Processing Record 8 of Set 13 | ginir
# Processing Record 9 of Set 13 | baihar
# Processing Record 10 of Set 13 | teya
# Processing Record 11 of Set 13 | bundaberg
# Processing Record 12 of Set 13 | yakeshi
# Processing Record 13 of Set 13 | dasoguz
# Processing Record 14 of Set 13 | lucapa
# Processing Record 15 of Set 13 | malacacheta
# Processing Record 16 of Set 13 | zheleznodorozhnyy
# Processing Record 17 of Set 13 | alghero
# Processing Record 18 of Set 13 | mount gambier
# Processing Record 19 of Set 13 | vorontsovka
# Processing Record 20 of Set 13 | wamba
# Processing Record 21 of Set 13 | nago
# Processing Record 22 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 13 | tazovskiy
# Processing Record 24 of Set 13 | tamluk
# Processing Record 25 of Set 13 | wellsford
# Processing Record 26 of Set 13 | moranbah
# Processing Record 27 of Set 13 | flinders
# Processing Record 28 of Set 13 | karpathos
# Processing Record 29 of Set 13 | udachnyy
# Processing Record 30 of Set 13 | vilhena
# Processing Record 31 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 13 | ndungu
# Processing Record 33 of Set 13 | jacksonville
# Processing Record 34 of Set 13 | yeppoon
# Processing Record 35 of Set 13 | alcacer do sal
# Processing Record 36 of Set 13 | kishapu
# Processing Record 37 of Set 13 | mangrol
# Processing Record 38 of Set 13 | nobres
# Processing Record 39 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 13 | tangier
# Processing Record 41 of Set 13 | bolshaya vishera
# City not found. Skipping...
# Processing Record 42 of Set 13 | sao joao da barra
# Processing Record 43 of Set 13 | balkanabat
# Processing Record 44 of Set 13 | qaqortoq
# Processing Record 45 of Set 13 | rundu
# Processing Record 46 of Set 13 | kandrian
# Processing Record 47 of Set 13 | ambon
# Processing Record 48 of Set 13 | chunskiy
# Processing Record 49 of Set 13 | xingyi
# Processing Record 50 of Set 13 | araripina
# Processing Record 1 of Set 14 | sanming
# Processing Record 2 of Set 14 | vilyuysk
# Processing Record 3 of Set 14 | north creek
# Processing Record 4 of Set 14 | pringsewu
# Processing Record 5 of Set 14 | sur
# Processing Record 6 of Set 14 | albanel
# Processing Record 7 of Set 14 | baghdad
# Processing Record 8 of Set 14 | the valley
# Processing Record 9 of Set 14 | mudon
# Processing Record 10 of Set 14 | sumter
# Processing Record 11 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 14 | krivosheino
# Processing Record 13 of Set 14 | big rapids
# Processing Record 14 of Set 14 | quatre cocos
# Processing Record 15 of Set 14 | contratacion
# Processing Record 16 of Set 14 | san antonio
# Processing Record 17 of Set 14 | eureka
# Processing Record 18 of Set 14 | milos
# Processing Record 19 of Set 14 | la rochelle
# Processing Record 20 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of Set 14 | amapa
# Processing Record 23 of Set 14 | acarau
# Processing Record 24 of Set 14 | qui nhon
# Processing Record 25 of Set 14 | vestmannaeyjar
# Processing Record 26 of Set 14 | edeia
# Processing Record 27 of Set 14 | roebourne
# Processing Record 28 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 29 of Set 14 | aklavik
# Processing Record 30 of Set 14 | gilbues
# Processing Record 31 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 32 of Set 14 | zalantun
# Processing Record 33 of Set 14 | pochutla
# Processing Record 34 of Set 14 | novoagansk
# Processing Record 35 of Set 14 | muros
# Processing Record 36 of Set 14 | murakami
# Processing Record 37 of Set 14 | danielskuil
# Processing Record 38 of Set 14 | izvoru berheciului
# Processing Record 39 of Set 14 | benalla
# Processing Record 40 of Set 14 | stolin
# Processing Record 41 of Set 14 | alakurtti
# Processing Record 42 of Set 14 | xiuyan
# Processing Record 43 of Set 14 | tigil
# Processing Record 44 of Set 14 | ostashkov
# Processing Record 45 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 14 | waingapu
# Processing Record 47 of Set 14 | angoche
# Processing Record 48 of Set 14 | ust-kuyga
# Processing Record 49 of Set 14 | gunjur
# Processing Record 50 of Set 14 | miraflores
# Processing Record 1 of Set 15 | ust-tarka
# Processing Record 2 of Set 15 | sorland
# Processing Record 3 of Set 15 | college
# Processing Record 4 of Set 15 | goderich
# Processing Record 5 of Set 15 | madaoua
# Processing Record 6 of Set 15 | hvide sande
# Processing Record 7 of Set 15 | uinskoye
# Processing Record 8 of Set 15 | port lincoln
# Processing Record 9 of Set 15 | itaqui
# Processing Record 10 of Set 15 | biak
# Processing Record 11 of Set 15 | praia
# Processing Record 12 of Set 15 | rong kwang
# Processing Record 13 of Set 15 | yakima
# Processing Record 14 of Set 15 | wuxue
# Processing Record 15 of Set 15 | san policarpo
# Processing Record 16 of Set 15 | svarstad
# Processing Record 17 of Set 15 | cabra
# Processing Record 18 of Set 15 | agapovka
# Processing Record 19 of Set 15 | kenai
# Processing Record 20 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 15 | sibu
# Processing Record 22 of Set 15 | maryborough
# Processing Record 23 of Set 15 | puri
# Processing Record 24 of Set 15 | surskoye
# Processing Record 25 of Set 15 | spencer
# Processing Record 26 of Set 15 | jingdezhen
# Processing Record 27 of Set 15 | henderson
# Processing Record 28 of Set 15 | turbana
# Processing Record 29 of Set 15 | plettenberg bay
# Processing Record 30 of Set 15 | adre
# Processing Record 31 of Set 15 | kichera
# Processing Record 32 of Set 15 | ornskoldsvik
# Processing Record 33 of Set 15 | durban
# Processing Record 34 of Set 15 | bay city
# Processing Record 35 of Set 15 | jining
# Processing Record 36 of Set 15 | buriti alegre
# Processing Record 37 of Set 15 | nhulunbuy
# Processing Record 38 of Set 15 | vardo
# Processing Record 39 of Set 15 | clarence town
# Processing Record 40 of Set 15 | guilin
# Processing Record 41 of Set 15 | cairns
# Processing Record 42 of Set 15 | perth
# Processing Record 43 of Set 15 | lendava
# Processing Record 44 of Set 15 | gravdal
# Processing Record 45 of Set 15 | san francisco
# Processing Record 46 of Set 15 | bataipora
# Processing Record 47 of Set 15 | fortuna
# Processing Record 48 of Set 15 | pierre
# Processing Record 49 of Set 15 | adrar
# Processing Record 50 of Set 15 | clifton
# Processing Record 1 of Set 16 | kirov
# Processing Record 2 of Set 16 | aldan
# Processing Record 3 of Set 16 | kaka
# Processing Record 4 of Set 16 | mount isa
# Processing Record 5 of Set 16 | tulun
# Processing Record 6 of Set 16 | paita
# Processing Record 7 of Set 16 | isla mujeres
# Processing Record 8 of Set 16 | awjilah
# Processing Record 9 of Set 16 | crestview
# Processing Record 10 of Set 16 | buncrana
# Processing Record 11 of Set 16 | magadan
# Processing Record 12 of Set 16 | zhigansk
# Processing Record 13 of Set 16 | pousat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# The number of cities in the city_data array of dictionaries

len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head(15)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yuancheng      CN  36.6520  107.7896     47.37        36         100
# 1       Benguela      AO -12.5763   13.4055     74.05        86           5
# 2        Mayumba      GA  -3.4320   10.6554     77.40        93          99
# 3        Manyana      BW -23.4000   21.7167     62.85        28           4
# 4          Jinka      ET   5.6500   36.6500     68.02        63          65
# 5   San Patricio      US  28.0170  -97.5169     93.92        43           3
# 6       Tasiilaq      GL  65.6145  -37.6368     30.36        62          50
# 7        Mataura      NZ -46.1927  168.8643     52.48        97         100
# 8     Codrington      AU -38.2667  141.9667     62.17        71         100
# 9        Rikitea      PF -23.1203 -134.9692     77.61        73          99
# 10        Dikson      RU  73.5069   80.5464     32.81        98         100
# 11       Kokkola      FI  63.8385   23.1307     44.76        71           0
# 12      Freeport      US  40.6576  -73.5832     75.27        76         100
# 13       Ushuaia      AR -54.8000  -68.3000     42.46        93          75
# 14        Avarua      CK -21.2078 -159.7750     82.45        83         100
#
#     Wind Speed Current Description
# 0         1.70     overcast clouds
# 1         4.38           clear sky
# 2         5.70     overcast clouds
# 3         2.95           clear sky
# 4         3.85       broken clouds
# 5        15.95           clear sky
# 6         2.13    scattered clouds
# 7         3.36     overcast clouds
# 8        17.92          light rain
# 9        19.48     overcast clouds
# 10       13.67     overcast clouds
# 11        4.61           clear sky
# 12        9.22     overcast clouds
# 13       10.36       broken clouds
# 14       11.50     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
