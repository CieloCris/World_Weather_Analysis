# %%
# 1.- Import dependencies

import pandas as pd
import numpy as np
import json 
import requests
from citipy import citipy
import timeit


from datetime import datetime
from config import weather_api_key

# %%
# 2.- Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# 3.- Unpack lat_lngs zip object into a list. Because we only need to create a set of random latitudes and longitudes one time
lat_lngs = zip(lats, lngs)
lat_lngs

# one can only unzip a zipped tuple once before it is removed from the computer's memory
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on

# %%
# 4.- Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(22.759023768216437, 48.81228086698869), (55.927663818037814, 166.54029220131116), (-44.821808367039395, -105.51518555735232), (-8.67014827288611, -8.553195491704912), (-52.5744630074226, -93.95852703202489), (2.692066922940114, -16.633527058991433), (-20.39334416904137, -147.50565417131102), (-23.566435395639672, -136.4777086563555), (-16.357430887790528, 18.76348221949283), (29.61017542882118, 118.93396718984957), (-58.722686098046346, 165.6756972011093), (84.60480829627778, -108.13269677266473), (24.87511319597664, 53.54898344988041), (78.81145748685898, 133.57079734681201), (-68.52504357978128, 161.43934360661325), (-23.083087270775806, -55.690352185814035), (-83.12057545201175, 66.2316185180967), (1.0351558125205855, -161.10023333345777), (12.368553070502628, 25.484436398076326), (-53.16962788759619, 81.65226624438935), (-35.40576230968415, 109.28477874585474), (62.5240867850394, 98.89478544591265), (41.28644776764574, -89.42197401663036), (-67.03988922403653, -84.26241903510348), (46.20735434617163, 162.23710675689438), (44.22156820295433, 81.75424754261991), (16.900861594126525, 39.29340712455826), (55.736708859273904, 132.12931408227695), (-23.081152143195794, 44.141928246064225), (85.37043578200104, -3.9851443981443992), (42.75300475854448, -30.947839470983865), (-51.654562083390815, -161.94109233748193), (16.273548352605232, 132.63959202088085), (-76.62025312042539, 63.59483279963973), (20.511945281909192, -108.02734625165643), (79.68218173861419, -17.058868829544423), (-32.573601099740564, 16.87569126047279), (-70.6095173336478, 168.61955761548865), (57.74501676460645, -111.54019670221078), (-9.223749333803582, -141.36502723804392), (-17.075997145285413, -3.753255562708432), (16.12334528099221, -53.562468630029755), (-82.26501487279074, 28.994503937353358), (-12.50758177212542, -144.02026827188945), (18.468593175186555, -115.59474586383382), (-85.19545710536957, 146.4618463730697), (-68.810359707836, 34.72400094838119), (66.83919222893664, -129.21482749179378), (85.64614880797976, 98.34451671946078), (42.693755330225656, -24.598690098486742), (10.207911204224914, 59.43601102796811), (-83.01898203536754, -163.79085785250183), (79.67188991151494, -101.00311249835829), (45.61196122094819, 92.23382043841326), (-53.35953227362372, -122.80483392002554), (88.66616132916306, -149.280988540371), (-11.27847118353155, -121.50395102768903), (26.99277621973995, 49.23250307773506), (-67.69000789761637, -108.68898687092191), (53.04285617224295, -113.92442397072799), (73.26912940023576, 141.65857081161965), (4.253217175427309, 104.64864131784202), (-64.54912294547222, -171.22431422468708), (47.32686852805358, 157.13439411251733), (6.016888645987876, -152.50413000725044), (32.280425864083554, -166.9574433391662), (-19.476487685230637, 0.7272770744832826), (-88.84111277722138, -130.91746077859435), (-29.548584377599823, 149.21927483891375), (25.409274710438424, 124.25749083738413), (-82.43807729228452, -40.493857406425064), (10.239424789973427, 113.35493405510692), (62.63131398766015, 74.49265013772043), (-8.722902190154116, 52.69224940002982), (-62.20503784460831, 100.67701158927412), (76.86230053202758, -30.790316616037813), (64.23045764795685, -28.304098432306233), (64.79648435361227, 144.31010505174453), (-13.815115136603893, 62.33898291428591), (19.224207656547264, 65.35978619762409), (69.75705004234058, -30.23118946511744), (-19.079954936678917, -93.82862911028876), (-84.32630931838835, -162.2537746314997), (-67.30572035441074, 74.76153676736394), (-71.58657652219577, -142.45358560969484), (63.481326475921804, -164.25162720737654), (-62.116956416939885, -123.53889429277987), (12.078096476726671, 130.79567411498113), (-87.71324621960083, -25.859257131880298), (-41.043970156824514, -69.8670697086592), (-70.87479091819522, -127.33237041099252), (54.28187376434269, 62.702973827533185), (46.84161009298424, -1.1897741462329634), (-11.86638894957359, 50.21462729047195), (28.401473635645473, 77.54485355844491), (-28.34480791369336, 15 ...

# %%
# 5.- Get the nearest city using the citipy module and create a list for holding the cities.
cities = []

# 6.- Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3eb5db8564aa00e965bac3a34dfb2af2

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | riyadh
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | bonthe
# Processing Record 6 of Set 1 | teahupoo
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | rundu
# Processing Record 9 of Set 1 | tunxi
# City not found. Skipping...
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | abu dhabi
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | capitan bado
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 1 | umm kaddadah
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | tura
# Processing Record 20 of Set 1 | peru
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | yining
# Processing Record 24 of Set 1 | ginda
# Processing Record 25 of Set 1 | tokur
# Processing Record 26 of Set 1 | sakaraha
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | san policarpo
# Processing Record 31 of Set 1 | bucerias
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | saldanha
# Processing Record 34 of Set 1 | athabasca
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | praia da vitoria
# Processing Record 45 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | hami
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 1 | calmar
# Processing Record 1 of Set 2 | deputatskiy
# Processing Record 2 of Set 2 | kerteh
# City not found. Skipping...
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | moree
# Processing Record 7 of Set 2 | ishigaki
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 10 of Set 2 | noyabrsk
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | olafsvik
# Processing Record 13 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 2 | grand gaube
# Processing Record 15 of Set 2 | dwarka
# Processing Record 16 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 2 | hualmay
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | nome
# Processing Record 20 of Set 2 | sulangan
# Processing Record 21 of Set 2 | san carlos de bariloche
# Processing Record 22 of Set 2 | oktyabrskoye
# Processing Record 23 of Set 2 | les herbiers
# Processing Record 24 of Set 2 | ambilobe
# Processing Record 25 of Set 2 | dankaur
# Processing Record 26 of Set 2 | oranjemund
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | malanje
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | phalaborwa
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | filadelfia
# Processing Record 36 of Set 2 | elko
# Processing Record 37 of Set 2 | lalomanu
# City not found. Skipping...
# Processing Record 38 of Set 2 | balikpapan
# Processing Record 39 of Set 2 | vanimo
# Processing Record 40 of Set 2 | poya
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | urfa
# City not found. Skipping...
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | delvada
# Processing Record 45 of Set 2 | bridlington
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | daru
# Processing Record 48 of Set 2 | ayan
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | tessalit
# Processing Record 4 of Set 3 | sao jose da coroa grande
# Processing Record 5 of Set 3 | maumere
# Processing Record 6 of Set 3 | tshikapa
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | zhigansk
# Processing Record 10 of Set 3 | dunedin
# Processing Record 11 of Set 3 | itarema
# Processing Record 12 of Set 3 | sistranda
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | imbituba
# Processing Record 15 of Set 3 | burica
# City not found. Skipping...
# Processing Record 16 of Set 3 | wajir
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | anjozorobe
# Processing Record 20 of Set 3 | odweyne
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | sur
# Processing Record 23 of Set 3 | kimle
# Processing Record 24 of Set 3 | el alto
# Processing Record 25 of Set 3 | morristown
# Processing Record 26 of Set 3 | lokosovo
# Processing Record 27 of Set 3 | nanyang
# Processing Record 28 of Set 3 | aykhal
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | los llanos de aridane
# Processing Record 31 of Set 3 | siniscola
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | port alfred
# Processing Record 34 of Set 3 | upington
# Processing Record 35 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 3 | rawson
# Processing Record 37 of Set 3 | otukpo
# Processing Record 38 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 3 | axim
# Processing Record 40 of Set 3 | ornskoldsvik
# Processing Record 41 of Set 3 | severo-yeniseyskiy
# Processing Record 42 of Set 3 | cayenne
# Processing Record 43 of Set 3 | conde
# Processing Record 44 of Set 3 | chapais
# Processing Record 45 of Set 3 | husavik
# Processing Record 46 of Set 3 | pangody
# Processing Record 47 of Set 3 | ternate
# Processing Record 48 of Set 3 | matameye
# City not found. Skipping...
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | sibsagar
# Processing Record 1 of Set 4 | palamos
# Processing Record 2 of Set 4 | den helder
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | port hardy
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | penzance
# Processing Record 8 of Set 4 | san matias
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | dhidhdhoo
# Processing Record 12 of Set 4 | pacific grove
# Processing Record 13 of Set 4 | dalvik
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | eufaula
# Processing Record 16 of Set 4 | khandbari
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | sola
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | paita
# Processing Record 21 of Set 4 | qaanaaq
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | puerto ayora
# Processing Record 24 of Set 4 | tuktoyaktuk
# Processing Record 25 of Set 4 | el cocuy
# Processing Record 26 of Set 4 | samarai
# Processing Record 27 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | tomatlan
# Processing Record 30 of Set 4 | qujing
# Processing Record 31 of Set 4 | fairbanks
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | khorramabad
# Processing Record 34 of Set 4 | nsanje
# Processing Record 35 of Set 4 | shancheng
# Processing Record 36 of Set 4 | luanda
# Processing Record 37 of Set 4 | tiznit
# Processing Record 38 of Set 4 | zemes
# Processing Record 39 of Set 4 | teofilo otoni
# Processing Record 40 of Set 4 | kloulklubed
# Processing Record 41 of Set 4 | niquero
# Processing Record 42 of Set 4 | griffith
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | yeppoon
# Processing Record 48 of Set 4 | tabuk
# Processing Record 49 of Set 4 | punta de bombon
# Processing Record 50 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 5 | svetlyy
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | jalu
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | pevek
# Processing Record 7 of Set 5 | adrar
# Processing Record 8 of Set 5 | tongchuan
# Processing Record 9 of Set 5 | platonovka
# Processing Record 10 of Set 5 | bredasdorp
# Processing Record 11 of Set 5 | anapskaya
# Processing Record 12 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | harper
# Processing Record 15 of Set 5 | susanville
# Processing Record 16 of Set 5 | ondangwa
# Processing Record 17 of Set 5 | virginia beach
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | san cristobal
# Processing Record 20 of Set 5 | eskisehir
# Processing Record 21 of Set 5 | mineiros
# Processing Record 22 of Set 5 | camacupa
# Processing Record 23 of Set 5 | bolotnoye
# Processing Record 24 of Set 5 | bethel
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | ilulissat
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | maragogi
# Processing Record 29 of Set 5 | ormara
# Processing Record 30 of Set 5 | pouembout
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | evensk
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | port blair
# Processing Record 35 of Set 5 | ponta do sol
# Processing Record 36 of Set 5 | east london
# Processing Record 37 of Set 5 | gamba
# Processing Record 38 of Set 5 | shelburne
# Processing Record 39 of Set 5 | yumen
# Processing Record 40 of Set 5 | siuna
# Processing Record 41 of Set 5 | namatanai
# Processing Record 42 of Set 5 | nacala
# Processing Record 43 of Set 5 | mbale
# Processing Record 44 of Set 5 | kamenka
# Processing Record 45 of Set 5 | mayumba
# Processing Record 46 of Set 5 | leshukonskoye
# Processing Record 47 of Set 5 | tasiilaq
# Processing Record 48 of Set 5 | roald
# Processing Record 49 of Set 5 | dingzhou
# Processing Record 50 of Set 5 | la palma
# Processing Record 1 of Set 6 | mucurapo
# Processing Record 2 of Set 6 | tazovskiy
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | benguela
# Processing Record 5 of Set 6 | markova
# Processing Record 6 of Set 6 | guangyuan
# Processing Record 7 of Set 6 | gustavo diaz ordaz
# Processing Record 8 of Set 6 | tahoua
# Processing Record 9 of Set 6 | isla mujeres
# Processing Record 10 of Set 6 | padang
# Processing Record 11 of Set 6 | fukue
# Processing Record 12 of Set 6 | bongaree
# Processing Record 13 of Set 6 | bolshiye uki
# City not found. Skipping...
# Processing Record 14 of Set 6 | camacha
# Processing Record 15 of Set 6 | thinadhoo
# Processing Record 16 of Set 6 | sisimiut
# Processing Record 17 of Set 6 | hervey bay
# Processing Record 18 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 6 | owen sound
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | atar
# Processing Record 22 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 6 | touros
# Processing Record 24 of Set 6 | abu road
# Processing Record 25 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 6 | nguruka
# Processing Record 27 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 6 | lodwar
# Processing Record 29 of Set 6 | nuuk
# Processing Record 30 of Set 6 | floro
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | pangnirtung
# Processing Record 33 of Set 6 | iraray
# Processing Record 34 of Set 6 | asau
# Processing Record 35 of Set 6 | pottsville
# Processing Record 36 of Set 6 | craig
# Processing Record 37 of Set 6 | naze
# Processing Record 38 of Set 6 | carnarvon
# Processing Record 39 of Set 6 | maningrida
# Processing Record 40 of Set 6 | guanica
# Processing Record 41 of Set 6 | liverpool
# Processing Record 42 of Set 6 | cockburn town
# Processing Record 43 of Set 6 | namuac
# Processing Record 44 of Set 6 | brae
# Processing Record 45 of Set 6 | cherskiy
# Processing Record 46 of Set 6 | sehithwa
# Processing Record 47 of Set 6 | road town
# Processing Record 48 of Set 6 | ambon
# Processing Record 49 of Set 6 | kananga
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | port keats
# Processing Record 2 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 7 | honningsvag
# Processing Record 4 of Set 7 | lima
# Processing Record 5 of Set 7 | belaya gora
# Processing Record 6 of Set 7 | prabumulih
# Processing Record 7 of Set 7 | vao
# Processing Record 8 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 7 | provideniya
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | maniitsoq
# Processing Record 13 of Set 7 | avera
# Processing Record 14 of Set 7 | kavieng
# Processing Record 15 of Set 7 | shiyan
# Processing Record 16 of Set 7 | mawlaik
# Processing Record 17 of Set 7 | alexandru ioan cuza
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | parkent
# Processing Record 20 of Set 7 | salekhard
# Processing Record 21 of Set 7 | presidente dutra
# Processing Record 22 of Set 7 | kargasok
# Processing Record 23 of Set 7 | bara
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | annamalainagar
# Processing Record 26 of Set 7 | srednekolymsk
# Processing Record 27 of Set 7 | minot
# Processing Record 28 of Set 7 | ostrovnoy
# Processing Record 29 of Set 7 | houston
# Processing Record 30 of Set 7 | pimenta bueno
# Processing Record 31 of Set 7 | nicolas bravo
# Processing Record 32 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 7 | loukhi
# Processing Record 34 of Set 7 | clyde river
# Processing Record 35 of Set 7 | anadyr
# Processing Record 36 of Set 7 | suratgarh
# Processing Record 37 of Set 7 | petauke
# Processing Record 38 of Set 7 | omagh
# Processing Record 39 of Set 7 | henties bay
# Processing Record 40 of Set 7 | khuzhir
# Processing Record 41 of Set 7 | sarishabari
# Processing Record 42 of Set 7 | comodoro rivadavia
# Processing Record 43 of Set 7 | kano
# Processing Record 44 of Set 7 | nhulunbuy
# Processing Record 45 of Set 7 | ugoofaaru
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | vostok
# Processing Record 48 of Set 7 | tigil
# Processing Record 49 of Set 7 | saint-pierre
# Processing Record 50 of Set 7 | goderich
# Processing Record 1 of Set 8 | salinopolis
# Processing Record 2 of Set 8 | faanui
# Processing Record 3 of Set 8 | harlingen
# Processing Record 4 of Set 8 | sao filipe
# Processing Record 5 of Set 8 | ukiah
# Processing Record 6 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 8 | lusambo
# Processing Record 9 of Set 8 | edd
# Processing Record 10 of Set 8 | pangai
# Processing Record 11 of Set 8 | sept-iles
# Processing Record 12 of Set 8 | porbandar
# Processing Record 13 of Set 8 | nouadhibou
# Processing Record 14 of Set 8 | dabakala
# Processing Record 15 of Set 8 | la ronge
# Processing Record 16 of Set 8 | shatalovo
# Processing Record 17 of Set 8 | san quintin
# Processing Record 18 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 8 | narsaq
# Processing Record 20 of Set 8 | neiafu
# Processing Record 21 of Set 8 | uarini
# Processing Record 22 of Set 8 | yate
# Processing Record 23 of Set 8 | tuatapere
# Processing Record 24 of Set 8 | newport
# Processing Record 25 of Set 8 | lata
# Processing Record 26 of Set 8 | teguise
# Processing Record 27 of Set 8 | belfast
# Processing Record 28 of Set 8 | iquitos
# Processing Record 29 of Set 8 | ambulu
# Processing Record 30 of Set 8 | mae hong son
# Processing Record 31 of Set 8 | mareeba
# Processing Record 32 of Set 8 | dallas
# Processing Record 33 of Set 8 | lavrentiya
# Processing Record 34 of Set 8 | flinders
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | kavaratti
# Processing Record 37 of Set 8 | novo aripuana
# Processing Record 38 of Set 8 | mogadishu
# Processing Record 39 of Set 8 | marrakesh
# Processing Record 40 of Set 8 | ulladulla
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | ban nahin
# Processing Record 43 of Set 8 | lashio
# Processing Record 44 of Set 8 | ilo
# Processing Record 45 of Set 8 | eirunepe
# Processing Record 46 of Set 8 | teknaf
# Processing Record 47 of Set 8 | alta floresta
# Processing Record 48 of Set 8 | mount gambier
# Processing Record 49 of Set 8 | tamandare
# Processing Record 50 of Set 8 | geraldton
# Processing Record 1 of Set 9 | saryagash
# Processing Record 2 of Set 9 | northam
# Processing Record 3 of Set 9 | aklavik
# Processing Record 4 of Set 9 | duz
# City not found. Skipping...
# Processing Record 5 of Set 9 | bilibino
# Processing Record 6 of Set 9 | westport
# Processing Record 7 of Set 9 | verkhnevilyuysk
# Processing Record 8 of Set 9 | san vicente
# Processing Record 9 of Set 9 | airai
# Processing Record 10 of Set 9 | korla
# Processing Record 11 of Set 9 | canandaigua
# Processing Record 12 of Set 9 | arraial do cabo
# Processing Record 13 of Set 9 | yilan
# Processing Record 14 of Set 9 | matara
# Processing Record 15 of Set 9 | eureka
# Processing Record 16 of Set 9 | the valley
# Processing Record 17 of Set 9 | hasaki
# Processing Record 18 of Set 9 | shanhetun
# Processing Record 19 of Set 9 | kinablangan
# Processing Record 20 of Set 9 | saint george
# Processing Record 21 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 22 of Set 9 | boundiali
# Processing Record 23 of Set 9 | bastrop
# Processing Record 24 of Set 9 | walvis bay
# Processing Record 25 of Set 9 | vanavara
# Processing Record 26 of Set 9 | guanare
# Processing Record 27 of Set 9 | bereda
# Processing Record 28 of Set 9 | maryanovka
# City not found. Skipping...
# Processing Record 29 of Set 9 | erzin
# Processing Record 30 of Set 9 | ariguani
# Processing Record 31 of Set 9 | inongo
# Processing Record 32 of Set 9 | tucupita
# Processing Record 33 of Set 9 | jaguarari
# Processing Record 34 of Set 9 | berlevag
# Processing Record 35 of Set 9 | ampanihy
# Processing Record 36 of Set 9 | chandur bazar
# Processing Record 37 of Set 9 | souillac
# Processing Record 38 of Set 9 | victor harbor
# Processing Record 39 of Set 9 | hit
# Processing Record 40 of Set 9 | zhuhai
# Processing Record 41 of Set 9 | urengoy
# Processing Record 42 of Set 9 | kandi
# Processing Record 43 of Set 9 | norrtalje
# Processing Record 44 of Set 9 | weligama
# Processing Record 45 of Set 9 | pareora
# Processing Record 46 of Set 9 | zhicheng
# Processing Record 47 of Set 9 | oriximina
# Processing Record 48 of Set 9 | bendigo
# Processing Record 49 of Set 9 | raton
# Processing Record 50 of Set 9 | itaberai
# Processing Record 1 of Set 10 | kattivakkam
# Processing Record 2 of Set 10 | tsiroanomandidy
# Processing Record 3 of Set 10 | antalaha
# Processing Record 4 of Set 10 | college
# Processing Record 5 of Set 10 | batagay
# Processing Record 6 of Set 10 | amapa
# Processing Record 7 of Set 10 | smithers
# Processing Record 8 of Set 10 | la asuncion
# Processing Record 9 of Set 10 | toamasina
# Processing Record 10 of Set 10 | mapiripan
# Processing Record 11 of Set 10 | ayutla
# Processing Record 12 of Set 10 | leningradskiy
# Processing Record 13 of Set 10 | severodvinsk
# Processing Record 14 of Set 10 | flin flon
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | dabat
# Processing Record 17 of Set 10 | itoman
# Processing Record 18 of Set 10 | zhangjiakou
# Processing Record 19 of Set 10 | mezen
# Processing Record 20 of Set 10 | salta
# Processing Record 21 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 10 | kang
# Processing Record 23 of Set 10 | denpasar
# Processing Record 24 of Set 10 | sharjah
# Processing Record 25 of Set 10 | la rioja
# Processing Record 26 of Set 10 | abdanan
# Processing Record 27 of Set 10 | kutum
# Processing Record 28 of Set 10 | cananea
# Processing Record 29 of Set 10 | bar harbor
# Processing Record 30 of Set 10 | redcliffe
# Processing Record 31 of Set 10 | kidal
# Processing Record 32 of Set 10 | dryden
# Processing Record 33 of Set 10 | burgeo
# Processing Record 34 of Set 10 | merauke
# Processing Record 35 of Set 10 | nemours
# Processing Record 36 of Set 10 | agadez
# Processing Record 37 of Set 10 | inuvik
# Processing Record 38 of Set 10 | azangaro
# Processing Record 39 of Set 10 | wageningen
# Processing Record 40 of Set 10 | carutapera
# Processing Record 41 of Set 10 | darhan
# Processing Record 42 of Set 10 | tonekabon
# Processing Record 43 of Set 10 | nakamura
# Processing Record 44 of Set 10 | takoradi
# Processing Record 45 of Set 10 | dembi dolo
# Processing Record 46 of Set 10 | montlucon
# Processing Record 47 of Set 10 | lar
# Processing Record 48 of Set 10 | bekhtery
# Processing Record 49 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 10 | sechura
# Processing Record 1 of Set 11 | antas
# Processing Record 2 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 11 | puerto escondido
# Processing Record 4 of Set 11 | hoi an
# Processing Record 5 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 11 | moose jaw
# Processing Record 7 of Set 11 | roebourne
# Processing Record 8 of Set 11 | oktyabrskiy
# Processing Record 9 of Set 11 | nieuw amsterdam
# Processing Record 10 of Set 11 | buin
# Processing Record 11 of Set 11 | maimon
# City not found. Skipping...
# Processing Record 12 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 14 of Set 11 | amahai
# Processing Record 15 of Set 11 | stokmarknes
# Processing Record 16 of Set 11 | robertsport
# Processing Record 17 of Set 11 | kenai
# Processing Record 18 of Set 11 | rocha
# Processing Record 19 of Set 11 | bon accord
# Processing Record 20 of Set 11 | bulgan
# Processing Record 21 of Set 11 | burnie
# Processing Record 22 of Set 11 | warri
# Processing Record 23 of Set 11 | kerouane
# Processing Record 24 of Set 11 | santa ana
# Processing Record 25 of Set 11 | taksimo
# Processing Record 26 of Set 11 | oxelosund
# Processing Record 27 of Set 11 | puerto narino
# Processing Record 28 of Set 11 | san ramon
# Processing Record 29 of Set 11 | veliki preslav
# Processing Record 30 of Set 11 | bandarbeyla
# Processing Record 31 of Set 11 | largo
# Processing Record 32 of Set 11 | soyo
# Processing Record 33 of Set 11 | coolum beach
# Processing Record 34 of Set 11 | liwonde
# Processing Record 35 of Set 11 | saint anthony
# Processing Record 36 of Set 11 | krasnoselkup
# Processing Record 37 of Set 11 | meadow lake
# Processing Record 38 of Set 11 | el dorado
# Processing Record 39 of Set 11 | turbat
# Processing Record 40 of Set 11 | la cruz
# Processing Record 41 of Set 11 | leczyca
# Processing Record 42 of Set 11 | laguna de perlas
# Processing Record 43 of Set 11 | taketa
# Processing Record 44 of Set 11 | yavaros
# Processing Record 45 of Set 11 | curitibanos
# Processing Record 46 of Set 11 | muli
# Processing Record 47 of Set 11 | renigunta
# Processing Record 48 of Set 11 | yerbogachen
# Processing Record 49 of Set 11 | mongo
# Processing Record 50 of Set 11 | fort nelson
# Processing Record 1 of Set 12 | prainha
# Processing Record 2 of Set 12 | williams lake
# Processing Record 3 of Set 12 | pitimbu
# Processing Record 4 of Set 12 | waipawa
# Processing Record 5 of Set 12 | puerto montt
# Processing Record 6 of Set 12 | ambunti
# Processing Record 7 of Set 12 | porto novo
# Processing Record 8 of Set 12 | boralday
# Processing Record 9 of Set 12 | nishihara
# Processing Record 10 of Set 12 | ryotsu
# Processing Record 11 of Set 12 | alihe
# Processing Record 12 of Set 12 | ombessa
# Processing Record 13 of Set 12 | taungdwingyi
# Processing Record 14 of Set 12 | erenhot
# Processing Record 15 of Set 12 | jand
# Processing Record 16 of Set 12 | grindavik
# Processing Record 17 of Set 12 | susangerd
# Processing Record 18 of Set 12 | muros
# Processing Record 19 of Set 12 | moranbah
# Processing Record 20 of Set 12 | bogorodskoye
# Processing Record 21 of Set 12 | selma
# Processing Record 22 of Set 12 | maine-soroa
# Processing Record 23 of Set 12 | swan hill
# Processing Record 24 of Set 12 | juneau
# Processing Record 25 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 12 | copiapo
# Processing Record 27 of Set 12 | innisfail
# Processing Record 28 of Set 12 | acapulco
# Processing Record 29 of Set 12 | puquio
# Processing Record 30 of Set 12 | toyooka
# Processing Record 31 of Set 12 | hambantota
# Processing Record 32 of Set 12 | mpika
# Processing Record 33 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 12 | caravelas
# Processing Record 35 of Set 12 | iralaya
# Processing Record 36 of Set 12 | biak
# Processing Record 37 of Set 12 | high level
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | desaguadero
# Processing Record 40 of Set 12 | juan aldama
# Processing Record 41 of Set 12 | ouadda
# Processing Record 42 of Set 12 | luderitz
# Processing Record 43 of Set 12 | enumclaw
# Processing Record 44 of Set 12 | ibra
# Processing Record 45 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 12 | namibe
# Processing Record 47 of Set 12 | hulan ergi
# Processing Record 48 of Set 12 | marica
# Processing Record 49 of Set 12 | napier
# Processing Record 50 of Set 12 | nizwa
# Processing Record 1 of Set 13 | karpathos
# Processing Record 2 of Set 13 | golyshmanovo
# Processing Record 3 of Set 13 | coffs harbour
# Processing Record 4 of Set 13 | healdsburg
# Processing Record 5 of Set 13 | malkangiri
# Processing Record 6 of Set 13 | laguna
# Processing Record 7 of Set 13 | ponnani
# Processing Record 8 of Set 13 | morshansk
# Processing Record 9 of Set 13 | segezha
# Processing Record 10 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 13 | soligalich
# Processing Record 12 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 13 | varlamovo
# Processing Record 14 of Set 13 | sulya
# Processing Record 15 of Set 13 | kuybyshevo
# Processing Record 16 of Set 13 | tias
# Processing Record 17 of Set 13 | praia
# Processing Record 18 of Set 13 | arlit
# Processing Record 19 of Set 13 | waddan
# Processing Record 20 of Set 13 | biltine
# Processing Record 21 of Set 13 | phuthaditjhaba
# Processing Record 22 of Set 13 | poum
# Processing Record 23 of Set 13 | nelson bay
# Processing Record 24 of Set 13 | tarko-sale
# Processing Record 25 of Set 13 | whitecourt
# Processing Record 26 of Set 13 | nador
# Processing Record 27 of Set 13 | arona
# Processing Record 28 of Set 13 | zhengjiatun
# Processing Record 29 of Set 13 | santa marta
# Processing Record 30 of Set 13 | huangzhou
# Processing Record 31 of Set 13 | pauini
# Processing Record 32 of Set 13 | aldan
# Processing Record 33 of Set 13 | mitsamiouli
# Processing Record 34 of Set 13 | wahlern
# Processing Record 35 of Set 13 | sibolga
# Processing Record 36 of Set 13 | ahome
# Processing Record 37 of Set 13 | jardim
# Processing Record 38 of Set 13 | provost
# Processing Record 39 of Set 13 | mana
# Processing Record 40 of Set 13 | havoysund
# Processing Record 41 of Set 13 | beckley
# Processing Record 42 of Set 13 | manggar
# Processing Record 43 of Set 13 | makakilo city
# Processing Record 44 of Set 13 | bambanglipuro
# Processing Record 45 of Set 13 | calderitas
# Processing Record 46 of Set 13 | puerto rico
# Processing Record 47 of Set 13 | nemuro
# Processing Record 48 of Set 13 | buraydah
# Processing Record 49 of Set 13 | port-gentil
# Processing Record 50 of Set 13 | kirakira
# Processing Record 1 of Set 14 | gejiu
# Processing Record 2 of Set 14 | sulurpeta
# City not found. Skipping...
# Processing Record 3 of Set 14 | nara
# Processing Record 4 of Set 14 | jaypur
# Processing Record 5 of Set 14 | khao wong
# Processing Record 6 of Set 14 | matrei
# City not found. Skipping...
# Processing Record 7 of Set 14 | dharchula
# Processing Record 8 of Set 14 | huarmey
# Processing Record 9 of Set 14 | tawaramoto
# Processing Record 10 of Set 14 | dolores
# Processing Record 11 of Set 14 | damietta
# Processing Record 12 of Set 14 | oistins
# Processing Record 13 of Set 14 | manoel urbano
# Processing Record 14 of Set 14 | ossora
# Processing Record 15 of Set 14 | ulaangom
# Processing Record 16 of Set 14 | grenada
# Processing Record 17 of Set 14 | kijang
# Processing Record 18 of Set 14 | pangoa
# Processing Record 19 of Set 14 | ereymentau
# Processing Record 20 of Set 14 | waingapu
# Processing Record 21 of Set 14 | umm lajj
# Processing Record 22 of Set 14 | sorong
# Processing Record 23 of Set 14 | vinh
# Processing Record 24 of Set 14 | hofn
# Processing Record 25 of Set 14 | sindor
# Processing Record 26 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 27 of Set 14 | saint-georges
# Processing Record 28 of Set 14 | baltasi
# Processing Record 29 of Set 14 | male
# Processing Record 30 of Set 14 | vardo
# Processing Record 31 of Set 14 | kajaani
# Processing Record 32 of Set 14 | jiwani
# Processing Record 33 of Set 14 | dingle
# Processing Record 34 of Set 14 | coahuayana
# Processing Record 35 of Set 14 | hokitika
# Processing Record 36 of Set 14 | kopavogur
# Processing Record 37 of Set 14 | tiarei
# Processing Record 38 of Set 14 | sioux lookout
# Processing Record 39 of Set 14 | karratha
# Processing Record 40 of Set 14 | pindiga
# Processing Record 41 of Set 14 | bobonong
# City not found. Skipping...
# Processing Record 42 of Set 14 | sibay
# Processing Record 43 of Set 14 | kitimat
# Processing Record 44 of Set 14 | gudiyattam
# City not found. Skipping...
# Processing Record 45 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 14 | jinan
# Processing Record 47 of Set 14 | lakes entrance
# Processing Record 48 of Set 14 | fonte boa
# Processing Record 49 of Set 14 | sumbe
# Processing Record 50 of Set 14 | media luna
# Processing Record 1 of Set 15 | aporawan
# City not found. Skipping...
# Processing Record 2 of Set 15 | baghdad
# Processing Record 3 of Set 15 | cheyenne
# Processing Record 4 of Set 15 | diamantino
# Processing Record 5 of Set 15 | karimganj
# Processing Record 6 of Set 15 | sauk rapids
# Processing Record 7 of Set 15 | mehamn
# Processing Record 8 of Set 15 | lhokseumawe
# Processing Record 9 of Set 15 | timbiqui
# Processing Record 10 of Set 15 | cabra
# Processing Record 11 of Set 15 | mgandu
# Processing Record 12 of Set 15 | coos bay
# Processing Record 13 of Set 15 | payo
# Processing Record 14 of Set 15 | viedma
# Processing Record 15 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 15 | babol
# Processing Record 17 of Set 15 | bull savanna
# Processing Record 18 of Set 15 | kushiro
# Processing Record 19 of Set 15 | nehe
# Processing Record 20 of Set 15 | cajica
# Processing Record 21 of Set 15 | atherton
# Processing Record 22 of Set 15 | novikovo
# Processing Record 23 of Set 15 | lyaskelya
# Processing Record 24 of Set 15 | ushtobe
# Processing Record 25 of Set 15 | turukhansk
# Processing Record 26 of Set 15 | huajuapan
# City not found. Skipping...
# Processing Record 27 of Set 15 | pangkalanbuun
# Processing Record 28 of Set 15 | boshan
# Processing Record 29 of Set 15 | nichinan
# Processing Record 30 of Set 15 | bignona
# Processing Record 31 of Set 15 | akyab
# Processing Record 32 of Set 15 | fomboni
# Processing Record 33 of Set 15 | vadgaon
# Processing Record 34 of Set 15 | bosaso
# Processing Record 35 of Set 15 | pirapo
# Processing Record 36 of Set 15 | soavinandriana
# Processing Record 37 of Set 15 | lincoln
# Processing Record 38 of Set 15 | sandwick
# Processing Record 39 of Set 15 | havre-saint-pierre
# Processing Record 40 of Set 15 | galveston
# Processing Record 41 of Set 15 | sobolevo
# Processing Record 42 of Set 15 | canavieiras
# Processing Record 43 of Set 15 | san andres
# Processing Record 44 of Set 15 | quzhou
# Processing Record 45 of Set 15 | bambari
# Processing Record 46 of Set 15 | perth
# Processing Record 47 of Set 15 | san patricio
# Processing Record 48 of Set 15 | kadykchan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Riyadh      SA  24.6877   46.7219     91.54        13           0
# 1   Nikolskoye      RU  59.7035   30.7861     49.80        97         100
# 2       Castro      BR -24.7911  -50.0119     64.22        75          25
# 3   Georgetown      MY   5.4112  100.3354     82.33        93          40
# 4       Bonthe      SL   7.5264  -12.5050     81.09        82          22
# 5     Teahupoo      PF -17.8333 -149.2667     76.96        79          15
# 6      Rikitea      PF -23.1203 -134.9692     77.54        81           6
# 7        Rundu      NA -17.9333   19.7667     61.00        23           0
# 8        Bluff      NZ -46.6000  168.3333     53.20        79          17
# 9  Yellowknife      CA  62.4560 -114.3525     36.12        64          75
#
#    Wind Speed Current Description
# 0       19.62           clear sky
# 1        3.91     overcast clouds
# 2        4.25    scattered clouds
# 3        5.01    scattered clouds
# 4        5.88          few clouds
# 5       18.07          light rain
# 6       20.42           clear sky
# 7        3.27           clear sky
# 8       17.29          few clouds
# 9        4.61       broken clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
